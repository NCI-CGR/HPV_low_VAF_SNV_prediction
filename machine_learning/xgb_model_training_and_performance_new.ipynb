# %% [markdown]
# # Notebook for HPV Triplicate Study

# %% [markdown]
# ####################################################### <br>
#     <font color='maroon'>
#     Updated on Nov. 21, 2023 <br>
#     <p><b>Author</b>:<br>
#     Sambit K. Mishra <br>
#     Cancer Genomics Research Laboratory <br>
#     Frederick National Laboratory <br>
#     Division of Cancer Epidemiology and Genetics <br>
#     National Cancer Institute </b>
#     <font color='black'> <br>
# ####################################################### <br>

# %% [markdown]
# This notebook includes the steps involving the training and testing of <b> extreme gradient boosting (XGBoost) </b> machine learning models for predicting true low/intermediate-VAF <b> intrahost single nucleotide variants (iSNVs) </b> in HPV. The splitting of the datasets into training and testing is performed at the sample-level instead of the iSNV level. The data files used for model training and testing in this notebook were generated using an in-house variant calling pipeline and a set of in-house scripts that processed the VCF files and parsed the variants, their replicate frequency and all the 31 features into a csv file. The notebook is indended to serve as reference for readers to understand how XGBoost model training and testing was performed in our study and more importantly, for reproducibility of the study results.
#
# We have included the training and testing steps for the 3 scenarios described in our study: <p>
# > <p> <b> 1. Machine learning with VAF filters (FM models) </b>
# > <p> <b> 2. Macine learning with VCFgenie without any low-VAF filters (VM models) </b> <p>
# > <p> <b> 3. Machine learning with VCFgenie with low-VAF filters (FVM models) </b> <p>

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns
import math
import os
import matplotlib.pyplot as plt
import glob
import random
from scipy import stats
from pathlib import Path
import warnings
from itertools import product
import joblib
warnings.filterwarnings("ignore") # Will suppress any unnecessary warnings

# ML libraries
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_auc_score, roc_curve, auc, classification_report
from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef
from sklearn.metrics import mean_squared_error, cohen_kappa_score, make_scorer
from sklearn.metrics import confusion_matrix, accuracy_score, average_precision_score, ConfusionMatrixDisplay

# %% [markdown]
# ## Define some custom functions

# %%
 # Plot settings
sns.set_style('ticks')

def remove_low_coverage_samples(df_snv_w_cov, min_cov_cutoff, coverage_column):
    """
    Updated to exclude minimum depth requirement.
    Remove iSNVs that do not meet quality control criteria: FAO > 0
        df_snv_w_cov: The dataframe with all SNVs and their features
        min_cov_cutoff: The minimum value for coverage
        coverage_column: The coverage column (FDP or FAO for Ion Torrent data)
    """
    df_snv_high_cov = df_snv_w_cov.copy()
    df_snv_high_cov = df_snv_high_cov.loc[df_snv_high_cov[coverage_column] >= min_cov_cutoff]
    df_snv_high_cov.reset_index(drop=True, inplace=True)
    return df_snv_high_cov
    
def create_balanced_datasets(X_train, y_train, true_label=1, false_label=0):
    """
    Create balanced datasets for training. The test data will remain imbalanced.
        seed_value : The seed for random state selection
        t_size : Size of the test data. Note that this is 30% of the entire data 
                (true label + false label), not 30% of each label. You may notice that 
                the test data for the individual labels (true label or false label) are not exactly 
                30% of the entire data. 
        true_label : The numeric label for the true variants
        false_label: The numeric label for the false variants
    """
    train_samples = {} # Dictionary in which we will store the training samples
    train_index_list = [] # Will keep track of the indices of the sampled rows in the training data.
                          # Depending on the value set for alpha, the number of unique indices
                          # should equal to the size of the training data.
    X_train.reset_index(inplace=True, drop=True)
    
    # If the training data is not balanced, then undersample the over-represented class
    # and create multiple training datasets.
    num_true = y_train.count(true_label) # Number of true labels
    num_false = y_train.count(false_label) # Number of false labels
    
    # Identify the over-represented class 
    if num_true > num_false:
        over_rep_class = true_label
        over_rep_count = num_true
        under_rep_class = false_label
        under_rep_count = num_false
    elif num_false > num_true:
        over_rep_class = false_label
        over_rep_count = num_false
        under_rep_class = true_label
        under_rep_count = num_true
    else:
        # Both classes are balanced
        train_samples['1'] = {}
        train_samples['1']['X_train'] = X_train
        train_samples['1']['y_train'] = y_train
        return train_samples, train_index_list
    
    # # Commenting out this debug info statement for now. Uncomment when needed.
    print ("\tTrain-test split resulted in imbalanced training data", flush=True)
    print (f"\tOver-represented class = {over_rep_class}, count = {over_rep_count}", flush=True)
    print (f"\tUnder-represented class = {under_rep_class}, count = {under_rep_count}", flush=True)
    print ("\tWill proceed by creating balanced training data.", flush=True)
    
    alpha = 5 # A sampling weight constant that determines the number of times
            # the over-represented class will be sampled.
    num_sample_iter = int(round(over_rep_count/under_rep_count)*alpha)
    sample_size = under_rep_count
    seed_list = list(range(1,num_sample_iter+1)) # The seeds we will use for each iteration of sampling.
                                                 # This is to make the results reproducible.
    # Identify the indices of the over-represented and under-represented class
    # and get the respective data in X_train.
    over_rep_indices = list(np.where(np.array(y_train) == over_rep_class)[0])
    X_train_over_rep = X_train.iloc[over_rep_indices]
    under_rep_indices = list(np.where(np.array(y_train) == under_rep_class)[0])
    X_train_under_rep = X_train.iloc[under_rep_indices]
   
    # Perform sampling
    for seed_i in seed_list:
#         print (f"Sampling iteration {seed_i}...", flush=True, end='')
#         print (sample_size)
#         print (len(X_train_over_rep))
#         print (len(X_train_under_rep))
        X_train_sample_i_over_rep= X_train_over_rep.sample(n=sample_size, replace=False, random_state=seed_i)
        y_train_sample_i_over_rep = [over_rep_class] * sample_size
        # Consolidate the training feature data for the under represented class
        # and over-represented class into a single data frame
        X_train_sample_i = X_train_sample_i_over_rep.append(X_train_under_rep)
        
        ind_i_list = X_train_sample_i.index.tolist()
    #     print (ind_i_list)
    #     break
        if len(train_index_list) == 0:
            train_index_list = ind_i_list
        else:    
            train_index_list.extend(ind_i_list)
        
        # Turn off reset index for de-bugging
        X_train_sample_i.reset_index(inplace=True, drop=True)
        # Consolidate the training labels for the under represented
        # and over represented classes
        y_train_sample_i = y_train_sample_i_over_rep  + [under_rep_class] * sample_size
        
        # Shuffle the rows. Otherwise the Top N rows will be over-rep class and 
        # bottom N rows will be under-rep class.
        X_train_sample_i_shuffled = X_train_sample_i.sample(frac=1, random_state=seed_i)
        shuffled_indices = X_train_sample_i_shuffled.index.to_list()
        #
        y_train_sample_i_shuffled = [y_train_sample_i[ind_i] for ind_i in shuffled_indices]
        train_samples[seed_i] = {}
        train_samples[seed_i]['X_train'] = X_train_sample_i_shuffled
        train_samples[seed_i]['y_train'] = y_train_sample_i_shuffled
    return train_samples, train_index_list
 
def get_ensemble_prediction(y_scores_all_models):
    """
    For a given testing point, get the median score across all the models.
    If the median score is >= 0.5, then label 1 else label 0. 
    """
    median_scores = list(y_scores_all_models.median(axis=1))
    median_labels = list(map(lambda x: 0 if (round(x,2) < 0.5) else 1, median_scores))
    return median_labels


def get_ensemble_prediction_scores(y_scores_all_models):
    """
    Return the median scores across all the models for a given test 
    data point.
    """
    median_scores = list(y_scores_all_models.median(axis=1))
    median_scores = [round(score_i,2) for score_i in median_scores]
    return median_scores

# %% [markdown]
# ## Performance without VCFgenie and with a lower and upper bound - <b> <font color='green'> FM models </b> </font>

# %% [markdown]
# ### Define input and output files

# %%
## Create output directory
outdir = '../results/'
Path(outdir).mkdir(parents=True, exist_ok=True)

# The input vcf .csv file
snv_sbs_file = '../data/SNV_data_wo_vcf_genie.csv'

# The output file that will include the performance metrics
perf_out_file_xgb = outdir + 'performance_FM.csv'

# %% [markdown]
# ### Define parameters and conditions

# %%
af_lower = [0.01,0.02,0.05,0.1]
af_upper = [0.5] # Updated to only consider a single, strict upper VAF limit of 50%.
                 # Any SNV with VAF > 50% is a major variant and will be excluded.
                 # We will only consider SNVs with VAF < 50%.
feature_cat = ['Moderate', 'Strict', 'Exhaustive']

# Below, we convert the replicate frequencies into their numerical values.
# 1 => Replicate frequency 3/3
# 0.67 => Replicate frequency 2/3
# 0.33 => Replicate frequency 1/3
true_var = [[1],[1,0.67]]
false_var = [[0.33], [0.33, 0.67]] # Skip if 0.67 is in both true_var and false_var

# %% [markdown]
# ### Define feature categories as a dictionary

# %%
feat_cat_dict = {'Moderate': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','GQ','MLLD','QUAL','REFB',
                'REVB','SAF','SAR','SRF','SRR','SSSB','STB','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Strict': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','MLLD','QUAL','REFB','REVB','SSSB','VARB', 
                           '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Exhaustive': ['AO','DP','FAO','FDP','FRO','FSAF','FSAR','FSRF','FSRR','FWDB',
                'FXX','GQ','HRUN','LEN','MLLD','QD','QUAL','RBI','REFB','REVB',
                'RO','SAF','SAR','SRF','SRR','SSSB','STB','STBP','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT',
                '3_PRIME_NUCLEOTIDE_CONTEXT']
                }

# %% [markdown]
# ### Generate combinations of conditions

# %%
param_combinations = list(product(af_lower, af_upper, feature_cat, true_var, false_var))
print (param_combinations)
print (f"Total combinations = {len(param_combinations)}")
# Out:
# [(0.01, 0.5, 'Moderate', [1], [0.33]), (0.01, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.01, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.01, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.01, 0.5, 'Strict', [1], [0.33]), (0.01, 0.5, 'Strict', [1], [0.33, 0.67]), (0.01, 0.5, 'Strict', [1, 0.67], [0.33]), (0.01, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.01, 0.5, 'Exhaustive', [1], [0.33]), (0.01, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.01, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.01, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Moderate', [1], [0.33]), (0.02, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.02, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.02, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Strict', [1], [0.33]), (0.02, 0.5, 'Strict', [1], [0.33, 0.67]), (0.02, 0.5, 'Strict', [1, 0.67], [0.33]), (0.02, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Exhaustive', [1], [0.33]), (0.02, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.02, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.02, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Moderate', [1], [0.33]), (0.05, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.05, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.05, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Strict', [1], [0.33]), (0.05, 0.5, 'Strict', [1], [0.33, 0.67]), (0.05, 0.5, 'Strict', [1, 0.67], [0.33]), (0.05, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Exhaustive', [1], [0.33]), (0.05, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.05, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.05, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Moderate', [1], [0.33]), (0.1, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.1, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.1, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Strict', [1], [0.33]), (0.1, 0.5, 'Strict', [1], [0.33, 0.67]), (0.1, 0.5, 'Strict', [1, 0.67], [0.33]), (0.1, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Exhaustive', [1], [0.33]), (0.1, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.1, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.1, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67])]
# Total combinations = 48

# %% [markdown]
# <b><i> Note that for some combinations in the above, the replicate frequency 0.67 (i.e., SNV occurring in 2/3 replicates) is used both for true variants and false variants. Example of such a combination is (0.1, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]). We will exclude such combinations in our analysis, which will result in 36 combinations (4x1x3x3) in total.

# %% [markdown]
# ### Run Xtreme Gradient Boosting iteratively on these conditions

# %%
df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

# We will consider the SNVs in each replicate set only once and perform
# training and testing for each replicate set independently.
df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')

# To eliminate the performance bias due to sampling, we will use a set of seeds to perform
# random sampling. Using just a single seed might bias the testing data sampled
# and a very good performance on just one iteration of testing dataset is highly indicative of
# performance bias.
# In each iteration, 25 samples will be randomly selected for training and 6 for testing.

# Changing to perform 50 iterations
seed_list = [10,20,3247,24,4501,25,79,299,1001,287,497,300,999,6,1,217,21,29,47,187,701,702,703,704,801,802,804,810,101,102,103,104,105,106,121,
             122,123,124,125,127,141,142,143,144,145,191,192,193,194,195]

for seed_i in seed_list:
    # Randomly select 6 samples for testing
    # Get all the sample IDs
    all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

    # Set the random sampling seed
    random.seed(seed_i)

    # We will pick 6 testing samples and make sure snvs from these samples
    # are not included in the training set.
    testing_set_samples = random.sample(all_sample_ids, k=6)
    print (f"testing samples = {testing_set_samples}")
    df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_testing.reset_index(drop=True, inplace=True)
    df_snvs_training.reset_index(drop=True, inplace=True)

    print (f"Running predictions for all parameter/feature combinations with seed {seed_i} ...", end="", flush=True)
    df_perf_seed_i = pd.DataFrame()
    for comb_i in param_combinations:
        af_lower_i, af_upper_i, feat_cat_i, true_var_i, false_var_i = comb_i
        # if not (af_lower_i == 0.1 and af_upper_i == 0.5 and feat_cat_i == 'Moderate' and true_var_i == [1] and false_var_i == [0.33] and seed_i == 24 and rep_set_i == 'Rep_set_2'):
        #     continue

        # Commenting these print statements to reduce the amount of output text in the notebook
        # Uncomment if you desire to see the combinations
        print (f"Evaluating with parameters: af_lower_i={af_lower_i}, af_upper_i={af_upper_i}, feat_cat_i={feat_cat_i}, true_var_i={true_var_i}, false_var_i={false_var_i}")

        # If the 2/3 variant is included in both the true variant and false variant
        # then exclude that combination
        if 0.67 in true_var_i and 0.67 in false_var_i:
            continue
        feature_cols = feat_cat_dict[feat_cat_i]

        # Prepare training data for this parameters combination
        df_snvs_training_comb_i = df_snvs_training.copy()
        df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['AF'] > af_lower_i) & 
                                                       (df_snvs_training_comb_i['AF'] < af_upper_i)]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for training
        X = df_snvs_training_comb_i[feature_cols]
        y = df_snvs_training_comb_i[target_cols].tolist()

        # Create balanced datasets
        train_sample, train_index_list = create_balanced_datasets(X,y)

        # Prepare the testing dataset for the current parameters combination
        df_snvs_testing_comb_i = df_snvs_testing.copy()
        df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['AF'] > af_lower_i) & 
                                                       (df_snvs_testing_comb_i['AF'] < af_upper_i)]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for testing
        X_test = df_snvs_testing_comb_i[feature_cols]
        y_test = df_snvs_testing_comb_i[target_cols].tolist()

        # Train XGB model
        num_jobs = 6
        n_trees = 100
        mdepth = 10
        xgb_model = XGBClassifier(use_label_encoder=False, 
                              booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                              n_estimators=n_trees, # number of trees, default = 100
                              eta=0.2, # this is learning rate, default = 0.3
                              max_depth=mdepth, # maximum depth of the tree, default = 6
                              gamma = 1, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                              reg_lambda = 1, # regularization parameter, defautl = 1
                              eval_metric = 'logloss')
        fpr_tpr = [] # Store all the fpr, tpr values for each model 
        auc_scores = []
        df_y_pred_all_models = pd.DataFrame()
        df_y_scores_all_models = pd.DataFrame()
        df_all_cv_scores = pd.DataFrame()
        df_feature_importances_all_models = pd.DataFrame()
        for model_i in list(train_sample.keys()):
            X_train_model_i = train_sample[model_i]['X_train']
            y_train_model_i = train_sample[model_i]['y_train']
    #         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
            X_train_model_i = X_train_model_i.apply(pd.to_numeric)
            xgb_model.fit(X_train_model_i,y_train_model_i)

            # Predict using model_i on the test data
            y_pred = xgb_model.predict(X_test)
            df_y_pred_all_models[f"Model_{model_i}"] = y_pred
            y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
            df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
            false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
            fpr_tpr.append([false_positive,true_positive])
            # Calculate ROC only if both true and false labels are present.
            # Otherwise, the function roc_auc_score returns error.
            if len(set(y_test)) == 2:
                auc_test = roc_auc_score(y_test, y_pred)
            else:
                auc_test = math.nan
            auc_scores.append(auc_test)
        # Calculate metrics only if y_test has both true and false iSNVs labels.
        # Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
        if len(set(y_test)) == 2:
            # Get the consensus predictions from all models
            y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

            # Calculate metrics on the consensus prediction
            auc_test = roc_auc_score(y_test, y_pred_consensus)

            # Calculate the F1 score
            F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

            # Calculate the mean-squared error
            mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

            # Calculate the accuracy
            accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

            # Calculate the MCC
            mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

            # Print the performance metrics on test data
            print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

            # Get the confusion matrix
            cm = confusion_matrix(y_test, y_pred_consensus)

            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
        else:
            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
            auc_test = math.nan
            mcc_test = math.nan
            F1_score_test = math.nan
            accuracy_test = math.nan
            mse_test = math.nan

        cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
                'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
                'F1_score', 'Accuracy', 'MSE']

        # Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
        df_tmp = pd.DataFrame(data=[[seed_i, true_var_i, false_var_i,af_lower_i,af_upper_i,feat_cat_i, 
                                     tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                                     accuracy_test, mse_test]], columns=cols)
        df_perf_seed_i = df_perf_seed_i.append(df_tmp)
    df_perf_out_xgb = df_perf_out_xgb.append(df_perf_seed_i)
    print ("Done!")
df_perf_out_xgb.to_csv(perf_out_file_xgb, index=False)
df_perf_out_xgb
# Out:
# testing samples = ['sample24', 'sample5', 'sample10', 'sample15', 'sample1', 'sample31']
# Running predictions for all parameter/feature combinations with seed 10 ...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.785 , F1 score = 0.441 , Mean-squared error = 0.174 , Accuracy = 0.826 , Matthews correlation coefficient = 0.402
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3412
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.763 , F1 score = 0.389 , Mean-squared error = 0.19 , Accuracy = 0.81 , Matthews correlation coefficient = 0.352
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 859
# 	Will proceed by creating balanced training data.
# AUC = 0.682 , F1 score = 0.429 , Mean-squared error = 0.272 , Accuracy = 0.728 , Matthews correlation coefficient = 0.293
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.81 , F1 score = 0.469 , Mean-squared error = 0.164 , Accuracy = 0.836 , Matthews correlation coefficient = 0.438
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3412
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.782 , F1 score = 0.402 , Mean-squared error = 0.191 , Accuracy = 0.809 , Matthews correlation coefficient = 0.373
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 859
# 	Will proceed by creating balanced training data.
# AUC = 0.682 , F1 score = 0.43 , Mean-squared error = 0.267 , Accuracy = 0.733 , Matthews correlation coefficient = 0.295
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.781 , F1 score = 0.455 , Mean-squared error = 0.158 , Accuracy = 0.842 , Matthews correlation coefficient = 0.412
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3412
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.76 , F1 score = 0.405 , Mean-squared error = 0.17 , Accuracy = 0.83 , Matthews correlation coefficient = 0.364
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2930
# 	Under-represented class = 1, count = 859
# 	Will proceed by creating balanced training data.
# AUC = 0.652 , F1 score = 0.395 , Mean-squared error = 0.282 , Accuracy = 0.718 , Matthews correlation coefficient = 0.247
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.772 , F1 score = 0.411 , Mean-squared error = 0.173 , Accuracy = 0.827 , Matthews correlation coefficient = 0.375
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.752 , F1 score = 0.361 , Mean-squared error = 0.194 , Accuracy = 0.806 , Matthews correlation coefficient = 0.327
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.651 , F1 score = 0.38 , Mean-squared error = 0.285 , Accuracy = 0.715 , Matthews correlation coefficient = 0.239
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.789 , F1 score = 0.431 , Mean-squared error = 0.168 , Accuracy = 0.832 , Matthews correlation coefficient = 0.399
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.782 , F1 score = 0.382 , Mean-squared error = 0.194 , Accuracy = 0.806 , Matthews correlation coefficient = 0.361
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.66 , F1 score = 0.389 , Mean-squared error = 0.282 , Accuracy = 0.718 , Matthews correlation coefficient = 0.251
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.775 , F1 score = 0.42 , Mean-squared error = 0.168 , Accuracy = 0.832 , Matthews correlation coefficient = 0.383
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.777 , F1 score = 0.395 , Mean-squared error = 0.176 , Accuracy = 0.824 , Matthews correlation coefficient = 0.368
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2889
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.644 , F1 score = 0.371 , Mean-squared error = 0.291 , Accuracy = 0.709 , Matthews correlation coefficient = 0.227
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.684 , F1 score = 0.532 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.351
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.626 , F1 score = 0.43 , Mean-squared error = 0.317 , Accuracy = 0.683 , Matthews correlation coefficient = 0.226
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.635 , F1 score = 0.532 , Mean-squared error = 0.339 , Accuracy = 0.661 , Matthews correlation coefficient = 0.267
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.682 , F1 score = 0.528 , Mean-squared error = 0.307 , Accuracy = 0.693 , Matthews correlation coefficient = 0.328
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.62 , F1 score = 0.426 , Mean-squared error = 0.358 , Accuracy = 0.642 , Matthews correlation coefficient = 0.207
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.65 , F1 score = 0.563 , Mean-squared error = 0.349 , Accuracy = 0.651 , Matthews correlation coefficient = 0.287
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.701 , F1 score = 0.556 , Mean-squared error = 0.25 , Accuracy = 0.75 , Matthews correlation coefficient = 0.385
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.631 , F1 score = 0.435 , Mean-squared error = 0.298 , Accuracy = 0.702 , Matthews correlation coefficient = 0.241
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.656 , F1 score = 0.557 , Mean-squared error = 0.321 , Accuracy = 0.679 , Matthews correlation coefficient = 0.306
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.604 , F1 score = 0.5 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.226
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.574 , F1 score = 0.409 , Mean-squared error = 0.371 , Accuracy = 0.629 , Matthews correlation coefficient = 0.167
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.662 , F1 score = 0.676 , Mean-squared error = 0.343 , Accuracy = 0.657 , Matthews correlation coefficient = 0.322
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.535 , F1 score = 0.435 , Mean-squared error = 0.456 , Accuracy = 0.544 , Matthews correlation coefficient = 0.075
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.543 , F1 score = 0.364 , Mean-squared error = 0.4 , Accuracy = 0.6 , Matthews correlation coefficient = 0.099
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.608 , F1 score = 0.658 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.216
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.607 , F1 score = 0.542 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.222
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.592 , F1 score = 0.444 , Mean-squared error = 0.357 , Accuracy = 0.643 , Matthews correlation coefficient = 0.205
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.646 , F1 score = 0.667 , Mean-squared error = 0.357 , Accuracy = 0.643 , Matthews correlation coefficient = 0.289
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample12', 'sample27', 'sample14', 'sample2', 'sample6', 'sample23']
# Running predictions for all parameter/feature combinations with seed 20 ...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.804 , F1 score = 0.534 , Mean-squared error = 0.123 , Accuracy = 0.877 , Matthews correlation coefficient = 0.489
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3419
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.448 , Mean-squared error = 0.141 , Accuracy = 0.859 , Matthews correlation coefficient = 0.409
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 809
# 	Will proceed by creating balanced training data.
# AUC = 0.642 , F1 score = 0.45 , Mean-squared error = 0.268 , Accuracy = 0.732 , Matthews correlation coefficient = 0.275
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.784 , F1 score = 0.518 , Mean-squared error = 0.123 , Accuracy = 0.877 , Matthews correlation coefficient = 0.467
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3419
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.761 , F1 score = 0.442 , Mean-squared error = 0.135 , Accuracy = 0.865 , Matthews correlation coefficient = 0.397
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 809
# 	Will proceed by creating balanced training data.
# AUC = 0.647 , F1 score = 0.458 , Mean-squared error = 0.271 , Accuracy = 0.729 , Matthews correlation coefficient = 0.28
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.774 , F1 score = 0.5 , Mean-squared error = 0.129 , Accuracy = 0.871 , Matthews correlation coefficient = 0.447
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3419
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.763 , F1 score = 0.432 , Mean-squared error = 0.144 , Accuracy = 0.856 , Matthews correlation coefficient = 0.389
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2989
# 	Under-represented class = 1, count = 809
# 	Will proceed by creating balanced training data.
# AUC = 0.648 , F1 score = 0.46 , Mean-squared error = 0.257 , Accuracy = 0.743 , Matthews correlation coefficient = 0.291
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.47 , Mean-squared error = 0.135 , Accuracy = 0.865 , Matthews correlation coefficient = 0.426
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.751 , F1 score = 0.404 , Mean-squared error = 0.138 , Accuracy = 0.862 , Matthews correlation coefficient = 0.365
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.628 , F1 score = 0.424 , Mean-squared error = 0.287 , Accuracy = 0.713 , Matthews correlation coefficient = 0.238
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.759 , F1 score = 0.465 , Mean-squared error = 0.127 , Accuracy = 0.873 , Matthews correlation coefficient = 0.414
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.75 , F1 score = 0.402 , Mean-squared error = 0.14 , Accuracy = 0.86 , Matthews correlation coefficient = 0.363
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.618 , F1 score = 0.41 , Mean-squared error = 0.29 , Accuracy = 0.71 , Matthews correlation coefficient = 0.221
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.763 , F1 score = 0.457 , Mean-squared error = 0.135 , Accuracy = 0.865 , Matthews correlation coefficient = 0.408
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.747 , F1 score = 0.391 , Mean-squared error = 0.146 , Accuracy = 0.854 , Matthews correlation coefficient = 0.352
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2943
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.627 , F1 score = 0.422 , Mean-squared error = 0.275 , Accuracy = 0.725 , Matthews correlation coefficient = 0.243
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.678 , F1 score = 0.571 , Mean-squared error = 0.297 , Accuracy = 0.703 , Matthews correlation coefficient = 0.347
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.693 , F1 score = 0.541 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.361
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.599 , F1 score = 0.564 , Mean-squared error = 0.398 , Accuracy = 0.602 , Matthews correlation coefficient = 0.198
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.73 , F1 score = 0.638 , Mean-squared error = 0.248 , Accuracy = 0.752 , Matthews correlation coefficient = 0.451
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.723 , F1 score = 0.579 , Mean-squared error = 0.25 , Accuracy = 0.75 , Matthews correlation coefficient = 0.413
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.582 , F1 score = 0.539 , Mean-squared error = 0.414 , Accuracy = 0.586 , Matthews correlation coefficient = 0.165
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.701 , F1 score = 0.603 , Mean-squared error = 0.287 , Accuracy = 0.713 , Matthews correlation coefficient = 0.385
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.677 , F1 score = 0.519 , Mean-squared error = 0.289 , Accuracy = 0.711 , Matthews correlation coefficient = 0.326
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.621 , F1 score = 0.579 , Mean-squared error = 0.375 , Accuracy = 0.625 , Matthews correlation coefficient = 0.244
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.771 , F1 score = 0.7 , Mean-squared error = 0.207 , Accuracy = 0.793 , Matthews correlation coefficient = 0.542
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.746 , F1 score = 0.632 , Mean-squared error = 0.184 , Accuracy = 0.816 , Matthews correlation coefficient = 0.51
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.447 , F1 score = 0.4 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = -0.107
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.645 , F1 score = 0.526 , Mean-squared error = 0.31 , Accuracy = 0.69 , Matthews correlation coefficient = 0.297
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.729 , F1 score = 0.6 , Mean-squared error = 0.211 , Accuracy = 0.789 , Matthews correlation coefficient = 0.457
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.447 , F1 score = 0.364 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = -0.109
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.668 , F1 score = 0.571 , Mean-squared error = 0.31 , Accuracy = 0.69 , Matthews correlation coefficient = 0.33
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.729 , F1 score = 0.6 , Mean-squared error = 0.211 , Accuracy = 0.789 , Matthews correlation coefficient = 0.457
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.5 , F1 score = 0.457 , Mean-squared error = 0.5 , Accuracy = 0.5 , Matthews correlation coefficient = 0.0
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample6', 'sample25', 'sample4', 'sample10', 'sample20', 'sample26']
# Running predictions for all parameter/feature combinations with seed 3247 ...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.622 , F1 score = 0.32 , Mean-squared error = 0.176 , Accuracy = 0.824 , Matthews correlation coefficient = 0.222
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2268
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.614 , F1 score = 0.28 , Mean-squared error = 0.184 , Accuracy = 0.816 , Matthews correlation coefficient = 0.187
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 497
# 	Will proceed by creating balanced training data.
# AUC = 0.57 , F1 score = 0.344 , Mean-squared error = 0.312 , Accuracy = 0.688 , Matthews correlation coefficient = 0.14
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.621 , F1 score = 0.318 , Mean-squared error = 0.178 , Accuracy = 0.822 , Matthews correlation coefficient = 0.219
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2268
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.621 , F1 score = 0.288 , Mean-squared error = 0.186 , Accuracy = 0.814 , Matthews correlation coefficient = 0.196
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 497
# 	Will proceed by creating balanced training data.
# AUC = 0.57 , F1 score = 0.351 , Mean-squared error = 0.324 , Accuracy = 0.676 , Matthews correlation coefficient = 0.136
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.624 , F1 score = 0.326 , Mean-squared error = 0.169 , Accuracy = 0.831 , Matthews correlation coefficient = 0.231
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2268
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.613 , F1 score = 0.282 , Mean-squared error = 0.177 , Accuracy = 0.823 , Matthews correlation coefficient = 0.19
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2011
# 	Under-represented class = 1, count = 497
# 	Will proceed by creating balanced training data.
# AUC = 0.564 , F1 score = 0.329 , Mean-squared error = 0.307 , Accuracy = 0.693 , Matthews correlation coefficient = 0.131
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.639 , F1 score = 0.327 , Mean-squared error = 0.195 , Accuracy = 0.805 , Matthews correlation coefficient = 0.228
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2207
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.637 , F1 score = 0.296 , Mean-squared error = 0.199 , Accuracy = 0.801 , Matthews correlation coefficient = 0.208
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.569 , F1 score = 0.344 , Mean-squared error = 0.318 , Accuracy = 0.682 , Matthews correlation coefficient = 0.135
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.623 , F1 score = 0.306 , Mean-squared error = 0.199 , Accuracy = 0.801 , Matthews correlation coefficient = 0.204
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2207
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.625 , F1 score = 0.278 , Mean-squared error = 0.21 , Accuracy = 0.79 , Matthews correlation coefficient = 0.186
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.575 , F1 score = 0.359 , Mean-squared error = 0.328 , Accuracy = 0.672 , Matthews correlation coefficient = 0.142
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.646 , F1 score = 0.337 , Mean-squared error = 0.19 , Accuracy = 0.81 , Matthews correlation coefficient = 0.241
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2207
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.648 , F1 score = 0.31 , Mean-squared error = 0.192 , Accuracy = 0.808 , Matthews correlation coefficient = 0.225
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1961
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.567 , F1 score = 0.343 , Mean-squared error = 0.32 , Accuracy = 0.68 , Matthews correlation coefficient = 0.131
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.538 , F1 score = 0.262 , Mean-squared error = 0.293 , Accuracy = 0.707 , Matthews correlation coefficient = 0.087
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.56 , F1 score = 0.293 , Mean-squared error = 0.283 , Accuracy = 0.717 , Matthews correlation coefficient = 0.117
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.52 , F1 score = 0.347 , Mean-squared error = 0.424 , Accuracy = 0.576 , Matthews correlation coefficient = 0.042
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.501 , F1 score = 0.207 , Mean-squared error = 0.332 , Accuracy = 0.668 , Matthews correlation coefficient = 0.001
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.528 , F1 score = 0.243 , Mean-squared error = 0.303 , Accuracy = 0.697 , Matthews correlation coefficient = 0.054
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.507 , F1 score = 0.317 , Mean-squared error = 0.431 , Accuracy = 0.569 , Matthews correlation coefficient = 0.015
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.529 , F1 score = 0.249 , Mean-squared error = 0.304 , Accuracy = 0.696 , Matthews correlation coefficient = 0.065
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.544 , F1 score = 0.271 , Mean-squared error = 0.3 , Accuracy = 0.7 , Matthews correlation coefficient = 0.083
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.504 , F1 score = 0.318 , Mean-squared error = 0.436 , Accuracy = 0.564 , Matthews correlation coefficient = 0.009
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 175
# 	Under-represented class = 1, count = 52
# 	Will proceed by creating balanced training data.
# AUC = 0.438 , F1 score = 0.174 , Mean-squared error = 0.555 , Accuracy = 0.445 , Matthews correlation coefficient = -0.16
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# ...
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3168
# 	Under-represented class = 1, count = 906
# 	Will proceed by creating balanced training data.
# AUC = 0.648 , F1 score = 0.375 , Mean-squared error = 0.399 , Accuracy = 0.601 , Matthews correlation coefficient = 0.221
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.64 , F1 score = 0.278 , Mean-squared error = 0.36 , Accuracy = 0.64 , Matthews correlation coefficient = 0.178
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.609 , F1 score = 0.247 , Mean-squared error = 0.369 , Accuracy = 0.631 , Matthews correlation coefficient = 0.136
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.633 , F1 score = 0.329 , Mean-squared error = 0.392 , Accuracy = 0.608 , Matthews correlation coefficient = 0.187
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.635 , F1 score = 0.272 , Mean-squared error = 0.384 , Accuracy = 0.616 , Matthews correlation coefficient = 0.171
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.608 , F1 score = 0.245 , Mean-squared error = 0.385 , Accuracy = 0.615 , Matthews correlation coefficient = 0.135
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.651 , F1 score = 0.343 , Mean-squared error = 0.392 , Accuracy = 0.608 , Matthews correlation coefficient = 0.212
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.641 , F1 score = 0.279 , Mean-squared error = 0.358 , Accuracy = 0.642 , Matthews correlation coefficient = 0.18
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.616 , F1 score = 0.252 , Mean-squared error = 0.371 , Accuracy = 0.629 , Matthews correlation coefficient = 0.146
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.63 , F1 score = 0.326 , Mean-squared error = 0.396 , Accuracy = 0.604 , Matthews correlation coefficient = 0.184
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.419 , F1 score = 0.199 , Mean-squared error = 0.614 , Accuracy = 0.386 , Matthews correlation coefficient = -0.122
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.411 , F1 score = 0.183 , Mean-squared error = 0.607 , Accuracy = 0.393 , Matthews correlation coefficient = -0.131
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.508 , F1 score = 0.308 , Mean-squared error = 0.568 , Accuracy = 0.432 , Matthews correlation coefficient = 0.013
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.485 , F1 score = 0.247 , Mean-squared error = 0.589 , Accuracy = 0.411 , Matthews correlation coefficient = -0.023
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.485 , F1 score = 0.235 , Mean-squared error = 0.568 , Accuracy = 0.432 , Matthews correlation coefficient = -0.022
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.545 , F1 score = 0.337 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = 0.074
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.429 , F1 score = 0.208 , Mean-squared error = 0.619 , Accuracy = 0.381 , Matthews correlation coefficient = -0.108
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.421 , F1 score = 0.192 , Mean-squared error = 0.612 , Accuracy = 0.388 , Matthews correlation coefficient = -0.117
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.514 , F1 score = 0.314 , Mean-squared error = 0.573 , Accuracy = 0.427 , Matthews correlation coefficient = 0.023
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.436 , F1 score = 0.111 , Mean-squared error = 0.571 , Accuracy = 0.429 , Matthews correlation coefficient = -0.07
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.369 , F1 score = 0.078 , Mean-squared error = 0.602 , Accuracy = 0.398 , Matthews correlation coefficient = -0.141
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.523 , F1 score = 0.222 , Mean-squared error = 0.534 , Accuracy = 0.466 , Matthews correlation coefficient = 0.031
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.397 , F1 score = 0.1 , Mean-squared error = 0.643 , Accuracy = 0.357 , Matthews correlation coefficient = -0.116
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.276 , F1 score = 0.048 , Mean-squared error = 0.678 , Accuracy = 0.322 , Matthews correlation coefficient = -0.247
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.514 , F1 score = 0.217 , Mean-squared error = 0.551 , Accuracy = 0.449 , Matthews correlation coefficient = 0.018
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.421 , F1 score = 0.107 , Mean-squared error = 0.598 , Accuracy = 0.402 , Matthews correlation coefficient = -0.087
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.391 , F1 score = 0.083 , Mean-squared error = 0.559 , Accuracy = 0.441 , Matthews correlation coefficient = -0.116
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.542 , F1 score = 0.235 , Mean-squared error = 0.551 , Accuracy = 0.449 , Matthews correlation coefficient = 0.057
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
#     Seed True_Var_Def False_Var_Def  VAF_Lower_Limit  VAF_Upper_Limit  \
# 0     10          [1]        [0.33]             0.01              0.5
# 0     10          [1]  [0.33, 0.67]             0.01              0.5
# 0     10    [1, 0.67]        [0.33]             0.01              0.5
# 0     10          [1]        [0.33]             0.01              0.5
# 0     10          [1]  [0.33, 0.67]             0.01              0.5
# ..   ...          ...           ...              ...              ...
# 0    195          [1]  [0.33, 0.67]             0.10              0.5
# 0    195    [1, 0.67]        [0.33]             0.10              0.5
# 0    195          [1]        [0.33]             0.10              0.5
# 0    195          [1]  [0.33, 0.67]             0.10              0.5
# 0    195    [1, 0.67]        [0.33]             0.10              0.5
#
#    Feature_Category  Num_True_Var_Testing  Num_False_Var_Testing  TP   FP  \
# 0          Moderate                    68                    662  50  109
# 0          Moderate                    68                    726  48  131
# 0          Moderate                   132                    662  81  165
# 0            Strict                    68                    662  53  105
# 0            Strict                    68                    726  51  135
# ..              ...                   ...                    ...  ..  ...
# 0            Strict                     9                    109   2   73
# 0            Strict                    15                    103   9   59
# 0        Exhaustive                     9                    103   4   62
# 0        Exhaustive                     9                    109   3   60
# 0        Exhaustive                    15                    103  10   60
#
#      TN  FN       AUC    MCC  F1_score  Accuracy    MSE
# 0   553  18  0.785321  0.402     0.441     0.826  0.174
# 0   595  20  0.762721  0.352     0.389     0.810  0.190
# 0   497  51  0.682196  0.293     0.429     0.728  0.272
# 0   557  15  0.810401  0.438     0.469     0.836  0.164
# 0   591  17  0.782025  0.373     0.402     0.809  0.191
# ..  ...  ..       ...    ...       ...       ...    ...
# 0    36   7  0.276249 -0.247     0.048     0.322  0.678
# 0    44   6  0.513592  0.018     0.217     0.449  0.551
# 0    41   5  0.421251 -0.087     0.107     0.402  0.598
# 0    49   6  0.391437 -0.116     0.083     0.441  0.559
# 0    43   5  0.542071  0.057     0.235     0.449  0.551
#
# [1800 rows x 17 columns]

# %% [markdown]
# ## Performance with results from VCFgenie, but without a lower bound on VAF - <b> <font color='orange'> VM models </font> </b>

# %% [markdown]
# ### Define input and output files

# %%
# The input vcf .csv file
snv_sbs_file = '../data/SNV_data_with_vcf_genie.csv'
perf_out_file_xgb = outdir + 'performance_VM.csv'

# %% [markdown]
# ### Define parameters and conditions

# %%
af_upper = [0.5]
feature_cat = ['Moderate', 'Strict', 'Exhaustive']
true_var = [[1],[1,0.67]]
false_var = [[0.33], [0.33, 0.67]] # Skip if 0.67 is in both true_var and false_var

# %% [markdown]
# ### Define features categories as a dictionary

# %%
feat_cat_dict = {'Moderate': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','GQ','MLLD','QUAL','REFB',
                'REVB','SAF','SAR','SRF','SRR','SSSB','STB','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Strict': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','MLLD','QUAL','REFB','REVB','SSSB','VARB', 
                           '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Exhaustive': ['AO','DP','FAO','FDP','FRO','FSAF','FSAR','FSRF','FSRR','FWDB',
                'FXX','GQ','HRUN','LEN','MLLD','QD','QUAL','RBI','REFB','REVB',
                'RO','SAF','SAR','SRF','SRR','SSSB','STB','STBP','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT',
                '3_PRIME_NUCLEOTIDE_CONTEXT']
                }

# %% [markdown]
# ### Generate combinations of conditions

# %%
param_combinations = list(product(af_upper, feature_cat, true_var, false_var))
print (param_combinations)
print (f"Total combinations = {len(param_combinations)}")
# Out:
# [(0.5, 'Moderate', [1], [0.33]), (0.5, 'Moderate', [1], [0.33, 0.67]), (0.5, 'Moderate', [1, 0.67], [0.33]), (0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.5, 'Strict', [1], [0.33]), (0.5, 'Strict', [1], [0.33, 0.67]), (0.5, 'Strict', [1, 0.67], [0.33]), (0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.5, 'Exhaustive', [1], [0.33]), (0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67])]
# Total combinations = 12

# %% [markdown]
# ### Run Xtreme Gradient Boosting iteratively on these conditions

# %%
df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

# Read the file that identifies those samples
df_sample_mut_cat = pd.read_csv('../data/sample_selection_list.csv')

# Drop unnecessary columns
df_sample_mut_cat.drop(columns=['Sample_ID'], inplace=True)
df_sample_mut_cat.rename(columns={'Sample_ID_dummy': 'sample_id'}, inplace=True)

df_snv_sbs = df_snv_sbs.merge(df_sample_mut_cat, on='sample_id', how='left')

df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')

# To eliminate the performance bias due to sampling, we will use a set of seeds to perform
# random sampling. Using just a single seed might bias the testing data sampled
# and a very good performance on just one iteration of testing dataset is highly indicative of
# performance bias.
# In each iteration, 25 samples will be randomly selected for training and 6 for testing.


# Changing to perform 50 iterations
seed_list = [10,20,3247,24,4501,25,79,299,1001,287,497,300,999,6,1,217,21,29,47,187,701,702,703,704,801,802,804,810,101,102,103,104,105,106,121,
             122,123,124,125,127,141,142,143,144,145,191,192,193,194,195]


for seed_i in seed_list:
    # Randomly select 6 samples for testing 
    # Get all the sample IDs
    all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

    # Set the random sampling seed
    random.seed(seed_i)

    # We will pick 6 samples for testing
    testing_set_samples = random.sample(all_sample_ids, k=6)
    print (f"testing samples = {testing_set_samples}")
    df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_testing.reset_index(drop=True, inplace=True)
    df_snvs_training.reset_index(drop=True, inplace=True)

    print (f"Running predictions for all parameter/feature combinations with seed {seed_i}...", end="", flush=True)
    df_perf_seed_i = pd.DataFrame()
    for comb_i in param_combinations:
        af_upper_i, feat_cat_i, true_var_i, false_var_i = comb_i
        print (f"Evaluating with parameters: af_upper_i={af_upper_i}, feat_cat_i={feat_cat_i}, true_var_i={true_var_i}, false_var_i={false_var_i}")

        # If the 2/3 variant is included in both the true variant and false variant
        # then exclude that combination
        if 0.67 in true_var_i and 0.67 in false_var_i:
            continue
        feature_cols = feat_cat_dict[feat_cat_i]

        # Prepare training data for this parameters combination
        df_snvs_training_comb_i = df_snvs_training.copy()
        df_snvs_training_comb_i = df_snvs_training_comb_i.loc[df_snvs_training_comb_i['AF'] < af_upper_i]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for training
        X = df_snvs_training_comb_i[feature_cols]
        y = df_snvs_training_comb_i[target_cols].tolist()

        # Create balanced datasets
        train_sample, train_index_list = create_balanced_datasets(X,y)

        # Prepare the testing dataset for the current paramters combination
        df_snvs_testing_comb_i = df_snvs_testing.copy()
        df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[df_snvs_testing_comb_i['AF'] < af_upper_i]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for testing
        X_test = df_snvs_testing_comb_i[feature_cols]
        y_test = df_snvs_testing_comb_i[target_cols].tolist()

        # Train XGB model
        num_jobs = 6
        n_trees = 100
        mdepth = 10
        xgb_model = XGBClassifier(use_label_encoder=False, 
                              booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                              n_estimators=n_trees, # number of trees, default = 100
                              eta=0.2, # this is learning rate, default = 0.3
                              max_depth=mdepth, # maximum depth of the tree, default = 6
                              gamma = 1, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                              reg_lambda = 1, # regularization parameter, defautl = 1
                              eval_metric = 'logloss')
        fpr_tpr = [] # Store all the fpr, tpr values for each model 
        auc_scores = []
        df_y_pred_all_models = pd.DataFrame()
        df_y_scores_all_models = pd.DataFrame()
        df_all_cv_scores = pd.DataFrame()
        df_feature_importances_all_models = pd.DataFrame()
        for model_i in list(train_sample.keys()):
            X_train_model_i = train_sample[model_i]['X_train']
            y_train_model_i = train_sample[model_i]['y_train']
    #         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
            X_train_model_i = X_train_model_i.apply(pd.to_numeric)
            xgb_model.fit(X_train_model_i,y_train_model_i)

            # Predict using model_i on the test data
            y_pred = xgb_model.predict(X_test)
            df_y_pred_all_models[f"Model_{model_i}"] = y_pred
            y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
            df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
            false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
            fpr_tpr.append([false_positive,true_positive])
            # Calculate ROC only if both true and false labels are present.
            # Otherwise, the function roc_auc_score returns error.
            if len(set(y_test)) == 2:
                auc_test = roc_auc_score(y_test, y_pred)
            else:
                auc_test = math.nan
            auc_scores.append(auc_test)
        # Calculate metrics only if y_test has both true and false iSNVs labels.
        # Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
        if len(set(y_test)) == 2:
            # Get the consensus predictions from all models
            y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

            # Calculate metrics on the consensus prediction
            auc_test = roc_auc_score(y_test, y_pred_consensus)

            # Calculate the F1 score
            F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

            # Calculate the mean-squared error
            mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

            # Calculate the accuracy
            accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

            # Calculate the MCC
            mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

            # Print the performance metrics on test data
            # Uncomment to see the metrics for each combination
            print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

            # Get the confusion matrix
            cm = confusion_matrix(y_test, y_pred_consensus)

            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
        else:
            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
            auc_test = math.nan
            mcc_test = math.nan
            F1_score_test = math.nan
            accuracy_test = math.nan
            mse_test = math.nan

        cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
                'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
                'F1_score', 'Accuracy', 'MSE']

        # Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
        df_tmp = pd.DataFrame(data=[[seed_i, true_var_i, false_var_i,math.nan,af_upper_i,feat_cat_i, 
                                     tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                                     accuracy_test, mse_test]], columns=cols)
        df_perf_seed_i = df_perf_seed_i.append(df_tmp)
        #break
    df_perf_out_xgb = df_perf_out_xgb.append(df_perf_seed_i)
    print ("Done!")
df_perf_out_xgb.to_csv(perf_out_file_xgb, index=False)
df_perf_out_xgb
# Out:
# testing samples = ['sample24', 'sample5', 'sample10', 'sample15', 'sample1', 'sample31']
# Running predictions for all parameter/feature combinations with seed 10...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.782 , F1 score = 0.467 , Mean-squared error = 0.156 , Accuracy = 0.844 , Matthews correlation coefficient = 0.421
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3407
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.755 , F1 score = 0.4 , Mean-squared error = 0.181 , Accuracy = 0.819 , Matthews correlation coefficient = 0.355
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 878
# 	Will proceed by creating balanced training data.
# AUC = 0.69 , F1 score = 0.445 , Mean-squared error = 0.26 , Accuracy = 0.74 , Matthews correlation coefficient = 0.312
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.804 , F1 score = 0.478 , Mean-squared error = 0.161 , Accuracy = 0.839 , Matthews correlation coefficient = 0.44
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3407
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.786 , F1 score = 0.424 , Mean-squared error = 0.181 , Accuracy = 0.819 , Matthews correlation coefficient = 0.391
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 878
# 	Will proceed by creating balanced training data.
# AUC = 0.695 , F1 score = 0.45 , Mean-squared error = 0.261 , Accuracy = 0.739 , Matthews correlation coefficient = 0.318
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.469 , Mean-squared error = 0.152 , Accuracy = 0.848 , Matthews correlation coefficient = 0.42
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3407
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.425 , Mean-squared error = 0.173 , Accuracy = 0.827 , Matthews correlation coefficient = 0.387
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2924
# 	Under-represented class = 1, count = 878
# 	Will proceed by creating balanced training data.
# AUC = 0.672 , F1 score = 0.422 , Mean-squared error = 0.275 , Accuracy = 0.725 , Matthews correlation coefficient = 0.28
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample12', 'sample27', 'sample14', 'sample2', 'sample6', 'sample23']
# Running predictions for all parameter/feature combinations with seed 20...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.518 , Mean-squared error = 0.12 , Accuracy = 0.88 , Matthews correlation coefficient = 0.466
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3414
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.777 , F1 score = 0.461 , Mean-squared error = 0.131 , Accuracy = 0.869 , Matthews correlation coefficient = 0.42
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.644 , F1 score = 0.453 , Mean-squared error = 0.259 , Accuracy = 0.741 , Matthews correlation coefficient = 0.283
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.763 , F1 score = 0.5 , Mean-squared error = 0.123 , Accuracy = 0.877 , Matthews correlation coefficient = 0.444
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3414
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.753 , F1 score = 0.432 , Mean-squared error = 0.138 , Accuracy = 0.862 , Matthews correlation coefficient = 0.385
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.641 , F1 score = 0.45 , Mean-squared error = 0.274 , Accuracy = 0.726 , Matthews correlation coefficient = 0.27
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.515 , Mean-squared error = 0.121 , Accuracy = 0.879 , Matthews correlation coefficient = 0.462
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3414
# 	Under-represented class = 1, count = 400
# 	Will proceed by creating balanced training data.
# AUC = 0.775 , F1 score = 0.454 , Mean-squared error = 0.135 , Accuracy = 0.865 , Matthews correlation coefficient = 0.413
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2983
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.627 , F1 score = 0.429 , Mean-squared error = 0.276 , Accuracy = 0.724 , Matthews correlation coefficient = 0.248
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample6', 'sample25', 'sample4', 'sample10', 'sample20', 'sample26']
# Running predictions for all parameter/feature combinations with seed 3247...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.625 , F1 score = 0.333 , Mean-squared error = 0.165 , Accuracy = 0.835 , Matthews correlation coefficient = 0.24
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2262
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.632 , F1 score = 0.311 , Mean-squared error = 0.174 , Accuracy = 0.826 , Matthews correlation coefficient = 0.222
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 512
# 	Will proceed by creating balanced training data.
# AUC = 0.578 , F1 score = 0.351 , Mean-squared error = 0.293 , Accuracy = 0.707 , Matthews correlation coefficient = 0.163
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.634 , F1 score = 0.346 , Mean-squared error = 0.167 , Accuracy = 0.833 , Matthews correlation coefficient = 0.252
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2262
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.623 , F1 score = 0.299 , Mean-squared error = 0.178 , Accuracy = 0.822 , Matthews correlation coefficient = 0.207
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 512
# 	Will proceed by creating balanced training data.
# AUC = 0.574 , F1 score = 0.352 , Mean-squared error = 0.311 , Accuracy = 0.689 , Matthews correlation coefficient = 0.148
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.62 , F1 score = 0.327 , Mean-squared error = 0.163 , Accuracy = 0.837 , Matthews correlation coefficient = 0.235
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2262
# 	Under-represented class = 1, count = 255
# 	Will proceed by creating balanced training data.
# AUC = 0.63 , F1 score = 0.311 , Mean-squared error = 0.171 , Accuracy = 0.829 , Matthews correlation coefficient = 0.222
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2005
# 	Under-represented class = 1, count = 512
# 	Will proceed by creating balanced training data.
# AUC = 0.567 , F1 score = 0.335 , Mean-squared error = 0.303 , Accuracy = 0.697 , Matthews correlation coefficient = 0.14
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample30', 'sample13', 'sample20', 'sample24', 'sample3', 'sample28']
# Running predictions for all parameter/feature combinations with seed 24...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.773 , F1 score = 0.428 , Mean-squared error = 0.262 , Accuracy = 0.738 , Matthews correlation coefficient = 0.374
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3217
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.773 , F1 score = 0.391 , Mean-squared error = 0.263 , Accuracy = 0.737 , Matthews correlation coefficient = 0.354
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 765
# 	Will proceed by creating balanced training data.
# AUC = 0.659 , F1 score = 0.484 , Mean-squared error = 0.351 , Accuracy = 0.649 , Matthews correlation coefficient = 0.274
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.766 , F1 score = 0.421 , Mean-squared error = 0.267 , Accuracy = 0.733 , Matthews correlation coefficient = 0.365
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3217
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.756 , F1 score = 0.372 , Mean-squared error = 0.278 , Accuracy = 0.722 , Matthews correlation coefficient = 0.329
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 765
# 	Will proceed by creating balanced training data.
# AUC = 0.665 , F1 score = 0.491 , Mean-squared error = 0.344 , Accuracy = 0.656 , Matthews correlation coefficient = 0.285
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.767 , F1 score = 0.422 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.366
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3217
# 	Under-represented class = 1, count = 361
# 	Will proceed by creating balanced training data.
# AUC = 0.755 , F1 score = 0.374 , Mean-squared error = 0.273 , Accuracy = 0.727 , Matthews correlation coefficient = 0.329
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2813
# 	Under-represented class = 1, count = 765
# 	Will proceed by creating balanced training data.
# AUC = 0.663 , F1 score = 0.489 , Mean-squared error = 0.346 , Accuracy = 0.654 , Matthews correlation coefficient = 0.283
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample20', 'sample9', 'sample25', 'sample23', 'sample27', 'sample2']
# Running predictions for all parameter/feature combinations with seed 4501...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.784 , F1 score = 0.449 , Mean-squared error = 0.151 , Accuracy = 0.849 , Matthews correlation coefficient = 0.411
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3231
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.762 , F1 score = 0.365 , Mean-squared error = 0.165 , Accuracy = 0.835 , Matthews correlation coefficient = 0.341
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 758
# 	Will proceed by creating balanced training data.
# AUC = 0.618 , F1 score = 0.44 , Mean-squared error = 0.302 , Accuracy = 0.698 , Matthews correlation coefficient = 0.233
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.776 , F1 score = 0.437 , Mean-squared error = 0.155 , Accuracy = 0.845 , Matthews correlation coefficient = 0.397
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3231
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.741 , F1 score = 0.338 , Mean-squared error = 0.178 , Accuracy = 0.822 , Matthews correlation coefficient = 0.309
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 758
# 	Will proceed by creating balanced training data.
# AUC = 0.618 , F1 score = 0.442 , Mean-squared error = 0.31 , Accuracy = 0.69 , Matthews correlation coefficient = 0.229
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.769 , F1 score = 0.432 , Mean-squared error = 0.155 , Accuracy = 0.845 , Matthews correlation coefficient = 0.39
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3231
# 	Under-represented class = 1, count = 398
# 	Will proceed by creating balanced training data.
# AUC = 0.742 , F1 score = 0.34 , Mean-squared error = 0.176 , Accuracy = 0.824 , Matthews correlation coefficient = 0.311
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2871
# 	Under-represented class = 1, count = 758
# 	Will proceed by creating balanced training data.
# AUC = 0.615 , F1 score = 0.437 , Mean-squared error = 0.311 , Accuracy = 0.689 , Matthews correlation coefficient = 0.224
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample13', 'sample6', 'sample20', 'sample12', 'sample31', 'sample28']
# Running predictions for all parameter/feature combinations with seed 25...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.675 , F1 score = 0.272 , Mean-squared error = 0.208 , Accuracy = 0.792 , Matthews correlation coefficient = 0.221
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2928
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.68 , F1 score = 0.245 , Mean-squared error = 0.217 , Accuracy = 0.783 , Matthews correlation coefficient = 0.209
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 754
# 	Will proceed by creating balanced training data.
# AUC = 0.603 , F1 score = 0.374 , Mean-squared error = 0.32 , Accuracy = 0.68 , Matthews correlation coefficient = 0.179
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.696 , F1 score = 0.287 , Mean-squared error = 0.211 , Accuracy = 0.789 , Matthews correlation coefficient = 0.244
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2928
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.678 , F1 score = 0.241 , Mean-squared error = 0.22 , Accuracy = 0.78 , Matthews correlation coefficient = 0.205
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 754
# 	Will proceed by creating balanced training data.
# AUC = 0.616 , F1 score = 0.391 , Mean-squared error = 0.311 , Accuracy = 0.689 , Matthews correlation coefficient = 0.202
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.676 , F1 score = 0.27 , Mean-squared error = 0.215 , Accuracy = 0.785 , Matthews correlation coefficient = 0.22
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2928
# 	Under-represented class = 1, count = 386
# 	Will proceed by creating balanced training data.
# AUC = 0.666 , F1 score = 0.232 , Mean-squared error = 0.222 , Accuracy = 0.778 , Matthews correlation coefficient = 0.191
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2560
# 	Under-represented class = 1, count = 754
# 	Will proceed by creating balanced training data.
# AUC = 0.612 , F1 score = 0.385 , Mean-squared error = 0.314 , Accuracy = 0.686 , Matthews correlation coefficient = 0.194
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample23', 'sample16', 'sample17', 'sample21', 'sample3', 'sample11']
# Running predictions for all parameter/feature combinations with seed 79...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.645 , F1 score = 0.254 , Mean-squared error = 0.287 , Accuracy = 0.713 , Matthews correlation coefficient = 0.179
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3296
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.633 , F1 score = 0.222 , Mean-squared error = 0.309 , Accuracy = 0.691 , Matthews correlation coefficient = 0.153
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 853
# 	Will proceed by creating balanced training data.
# AUC = 0.62 , F1 score = 0.367 , Mean-squared error = 0.331 , Accuracy = 0.669 , Matthews correlation coefficient = 0.192
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.666 , F1 score = 0.27 , Mean-squared error = 0.285 , Accuracy = 0.715 , Matthews correlation coefficient = 0.203
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3296
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.666 , F1 score = 0.244 , Mean-squared error = 0.308 , Accuracy = 0.692 , Matthews correlation coefficient = 0.189
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 853
# 	Will proceed by creating balanced training data.
# AUC = 0.607 , F1 score = 0.353 , Mean-squared error = 0.352 , Accuracy = 0.648 , Matthews correlation coefficient = 0.17
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.663 , F1 score = 0.26 , Mean-squared error = 0.313 , Accuracy = 0.687 , Matthews correlation coefficient = 0.194
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3296
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.663 , F1 score = 0.238 , Mean-squared error = 0.324 , Accuracy = 0.676 , Matthews correlation coefficient = 0.184
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2838
# 	Under-represented class = 1, count = 853
# 	Will proceed by creating balanced training data.
# AUC = 0.61 , F1 score = 0.356 , Mean-squared error = 0.34 , Accuracy = 0.66 , Matthews correlation coefficient = 0.175
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample17', 'sample24', 'sample27', 'sample28', 'sample31', 'sample16']
# Running predictions for all parameter/feature combinations with seed 299...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.455 , F1 score = 0.086 , Mean-squared error = 0.451 , Accuracy = 0.549 , Matthews correlation coefficient = -0.043
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3377
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.454 , F1 score = 0.075 , Mean-squared error = 0.432 , Accuracy = 0.568 , Matthews correlation coefficient = -0.043
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 881
# 	Will proceed by creating balanced training data.
# AUC = 0.484 , F1 score = 0.226 , Mean-squared error = 0.471 , Accuracy = 0.529 , Matthews correlation coefficient = -0.024
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.46 , F1 score = 0.089 , Mean-squared error = 0.463 , Accuracy = 0.537 , Matthews correlation coefficient = -0.038
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3377
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.477 , F1 score = 0.086 , Mean-squared error = 0.429 , Accuracy = 0.571 , Matthews correlation coefficient = -0.021
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 881
# 	Will proceed by creating balanced training data.
# AUC = 0.485 , F1 score = 0.229 , Mean-squared error = 0.474 , Accuracy = 0.526 , Matthews correlation coefficient = -0.022
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.445 , F1 score = 0.082 , Mean-squared error = 0.471 , Accuracy = 0.529 , Matthews correlation coefficient = -0.053
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3377
# 	Under-represented class = 1, count = 423
# 	Will proceed by creating balanced training data.
# AUC = 0.476 , F1 score = 0.086 , Mean-squared error = 0.451 , Accuracy = 0.549 , Matthews correlation coefficient = -0.021
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2919
# 	Under-represented class = 1, count = 881
# 	Will proceed by creating balanced training data.
# AUC = 0.468 , F1 score = 0.213 , Mean-squared error = 0.482 , Accuracy = 0.518 , Matthews correlation coefficient = -0.048
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample2', 'sample26', 'sample5', 'sample6', 'sample25', 'sample28']
# Running predictions for all parameter/feature combinations with seed 1001...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.687 , F1 score = 0.457 , Mean-squared error = 0.227 , Accuracy = 0.773 , Matthews correlation coefficient = 0.328
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3262
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.663 , F1 score = 0.401 , Mean-squared error = 0.241 , Accuracy = 0.759 , Matthews correlation coefficient = 0.272
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.655 , F1 score = 0.492 , Mean-squared error = 0.315 , Accuracy = 0.685 , Matthews correlation coefficient = 0.281
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.676 , F1 score = 0.441 , Mean-squared error = 0.237 , Accuracy = 0.763 , Matthews correlation coefficient = 0.307
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3262
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.652 , F1 score = 0.385 , Mean-squared error = 0.252 , Accuracy = 0.748 , Matthews correlation coefficient = 0.251
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.669 , F1 score = 0.509 , Mean-squared error = 0.305 , Accuracy = 0.695 , Matthews correlation coefficient = 0.306
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.66 , F1 score = 0.421 , Mean-squared error = 0.239 , Accuracy = 0.761 , Matthews correlation coefficient = 0.282
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3262
# 	Under-represented class = 1, count = 308
# 	Will proceed by creating balanced training data.
# AUC = 0.661 , F1 score = 0.397 , Mean-squared error = 0.245 , Accuracy = 0.755 , Matthews correlation coefficient = 0.267
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2822
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.656 , F1 score = 0.494 , Mean-squared error = 0.313 , Accuracy = 0.687 , Matthews correlation coefficient = 0.284
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample29', 'sample31', 'sample18', 'sample8', 'sample19', 'sample3']
# Running predictions for all parameter/feature combinations with seed 287...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.881 , F1 score = 0.684 , Mean-squared error = 0.189 , Accuracy = 0.811 , Matthews correlation coefficient = 0.63
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3939
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.839 , F1 score = 0.563 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.516
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 936
# 	Will proceed by creating balanced training data.
# AUC = 0.787 , F1 score = 0.707 , Mean-squared error = 0.232 , Accuracy = 0.768 , Matthews correlation coefficient = 0.543
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.891 , F1 score = 0.702 , Mean-squared error = 0.173 , Accuracy = 0.827 , Matthews correlation coefficient = 0.65
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3939
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.837 , F1 score = 0.559 , Mean-squared error = 0.27 , Accuracy = 0.73 , Matthews correlation coefficient = 0.511
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 936
# 	Will proceed by creating balanced training data.
# AUC = 0.784 , F1 score = 0.703 , Mean-squared error = 0.236 , Accuracy = 0.764 , Matthews correlation coefficient = 0.536
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.891 , F1 score = 0.702 , Mean-squared error = 0.173 , Accuracy = 0.827 , Matthews correlation coefficient = 0.65
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3939
# 	Under-represented class = 1, count = 426
# 	Will proceed by creating balanced training data.
# AUC = 0.847 , F1 score = 0.576 , Mean-squared error = 0.253 , Accuracy = 0.747 , Matthews correlation coefficient = 0.53
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3429
# 	Under-represented class = 1, count = 936
# 	Will proceed by creating balanced training data.
# AUC = 0.794 , F1 score = 0.714 , Mean-squared error = 0.227 , Accuracy = 0.773 , Matthews correlation coefficient = 0.555
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample8', 'sample21', 'sample27', 'sample20', 'sample3', 'sample18']
# Running predictions for all parameter/feature combinations with seed 497...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.786 , F1 score = 0.536 , Mean-squared error = 0.174 , Accuracy = 0.826 , Matthews correlation coefficient = 0.463
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.757 , F1 score = 0.429 , Mean-squared error = 0.212 , Accuracy = 0.788 , Matthews correlation coefficient = 0.368
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.644 , F1 score = 0.512 , Mean-squared error = 0.318 , Accuracy = 0.682 , Matthews correlation coefficient = 0.279
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.777 , F1 score = 0.523 , Mean-squared error = 0.181 , Accuracy = 0.819 , Matthews correlation coefficient = 0.446
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.756 , F1 score = 0.432 , Mean-squared error = 0.207 , Accuracy = 0.793 , Matthews correlation coefficient = 0.37
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.65 , F1 score = 0.521 , Mean-squared error = 0.314 , Accuracy = 0.686 , Matthews correlation coefficient = 0.29
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.795 , F1 score = 0.545 , Mean-squared error = 0.172 , Accuracy = 0.828 , Matthews correlation coefficient = 0.476
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3362
# 	Under-represented class = 1, count = 370
# 	Will proceed by creating balanced training data.
# AUC = 0.768 , F1 score = 0.438 , Mean-squared error = 0.21 , Accuracy = 0.79 , Matthews correlation coefficient = 0.382
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2984
# 	Under-represented class = 1, count = 748
# 	Will proceed by creating balanced training data.
# AUC = 0.642 , F1 score = 0.508 , Mean-squared error = 0.315 , Accuracy = 0.685 , Matthews correlation coefficient = 0.277
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample21', 'sample17', 'sample26', 'sample31', 'sample15', 'sample12']
# Running predictions for all parameter/feature combinations with seed 300...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2700
# 	Under-represented class = 1, count = 269
# 	Will proceed by creating balanced training data.
# AUC = 0.643 , F1 score = 0.429 , Mean-squared error = 0.167 , Accuracy = 0.833 , Matthews correlation coefficient = 0.352
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3109
# 	Under-represented class = 1, count = 269
# 	Will proceed by creating balanced training data.
# AUC = 0.645 , F1 score = 0.415 , Mean-squared error = 0.166 , Accuracy = 0.834 , Matthews correlation coefficient = 0.324
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2700
# 	Under-represented class = 1, count = 678
# 	Will proceed by creating balanced training data.
# ...
# 	Under-represented class = 1, count = 368
# 	Will proceed by creating balanced training data.
# AUC = 0.604 , F1 score = 0.137 , Mean-squared error = 0.301 , Accuracy = 0.699 , Matthews correlation coefficient = 0.097
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1895
# 	Under-represented class = 1, count = 650
# 	Will proceed by creating balanced training data.
# AUC = 0.565 , F1 score = 0.304 , Mean-squared error = 0.35 , Accuracy = 0.65 , Matthews correlation coefficient = 0.105
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample29', 'sample16', 'sample12', 'sample6', 'sample3', 'sample7']
# Running predictions for all parameter/feature combinations with seed 193...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.705 , F1 score = 0.245 , Mean-squared error = 0.232 , Accuracy = 0.768 , Matthews correlation coefficient = 0.225
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3060
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.7 , F1 score = 0.218 , Mean-squared error = 0.24 , Accuracy = 0.76 , Matthews correlation coefficient = 0.206
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.608 , F1 score = 0.336 , Mean-squared error = 0.307 , Accuracy = 0.693 , Matthews correlation coefficient = 0.173
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.718 , F1 score = 0.258 , Mean-squared error = 0.222 , Accuracy = 0.778 , Matthews correlation coefficient = 0.242
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3060
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.705 , F1 score = 0.226 , Mean-squared error = 0.231 , Accuracy = 0.769 , Matthews correlation coefficient = 0.214
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.623 , F1 score = 0.354 , Mean-squared error = 0.297 , Accuracy = 0.703 , Matthews correlation coefficient = 0.198
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.728 , F1 score = 0.259 , Mean-squared error = 0.233 , Accuracy = 0.767 , Matthews correlation coefficient = 0.247
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3060
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.707 , F1 score = 0.222 , Mean-squared error = 0.242 , Accuracy = 0.758 , Matthews correlation coefficient = 0.212
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2635
# 	Under-represented class = 1, count = 831
# 	Will proceed by creating balanced training data.
# AUC = 0.608 , F1 score = 0.335 , Mean-squared error = 0.315 , Accuracy = 0.685 , Matthews correlation coefficient = 0.171
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample20', 'sample21', 'sample4', 'sample24', 'sample23', 'sample17']
# Running predictions for all parameter/feature combinations with seed 194...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.656 , F1 score = 0.23 , Mean-squared error = 0.271 , Accuracy = 0.729 , Matthews correlation coefficient = 0.178
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2834
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.63 , F1 score = 0.185 , Mean-squared error = 0.287 , Accuracy = 0.713 , Matthews correlation coefficient = 0.137
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 731
# 	Will proceed by creating balanced training data.
# AUC = 0.601 , F1 score = 0.378 , Mean-squared error = 0.362 , Accuracy = 0.638 , Matthews correlation coefficient = 0.168
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.675 , F1 score = 0.248 , Mean-squared error = 0.257 , Accuracy = 0.743 , Matthews correlation coefficient = 0.202
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2834
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.656 , F1 score = 0.202 , Mean-squared error = 0.279 , Accuracy = 0.721 , Matthews correlation coefficient = 0.165
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 731
# 	Will proceed by creating balanced training data.
# AUC = 0.614 , F1 score = 0.391 , Mean-squared error = 0.336 , Accuracy = 0.664 , Matthews correlation coefficient = 0.193
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.643 , F1 score = 0.221 , Mean-squared error = 0.274 , Accuracy = 0.726 , Matthews correlation coefficient = 0.164
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2834
# 	Under-represented class = 1, count = 382
# 	Will proceed by creating balanced training data.
# AUC = 0.627 , F1 score = 0.182 , Mean-squared error = 0.292 , Accuracy = 0.708 , Matthews correlation coefficient = 0.133
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2485
# 	Under-represented class = 1, count = 731
# 	Will proceed by creating balanced training data.
# AUC = 0.602 , F1 score = 0.378 , Mean-squared error = 0.359 , Accuracy = 0.641 , Matthews correlation coefficient = 0.17
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample21', 'sample13', 'sample5', 'sample9', 'sample28', 'sample14']
# Running predictions for all parameter/feature combinations with seed 195...Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.669 , F1 score = 0.364 , Mean-squared error = 0.347 , Accuracy = 0.653 , Matthews correlation coefficient = 0.241
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3689
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.664 , F1 score = 0.352 , Mean-squared error = 0.344 , Accuracy = 0.656 , Matthews correlation coefficient = 0.232
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 921
# 	Will proceed by creating balanced training data.
# AUC = 0.658 , F1 score = 0.404 , Mean-squared error = 0.379 , Accuracy = 0.621 , Matthews correlation coefficient = 0.244
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.682 , F1 score = 0.372 , Mean-squared error = 0.363 , Accuracy = 0.637 , Matthews correlation coefficient = 0.259
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3689
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.672 , F1 score = 0.354 , Mean-squared error = 0.362 , Accuracy = 0.638 , Matthews correlation coefficient = 0.24
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 921
# 	Will proceed by creating balanced training data.
# AUC = 0.679 , F1 score = 0.42 , Mean-squared error = 0.387 , Accuracy = 0.613 , Matthews correlation coefficient = 0.275
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.686 , F1 score = 0.378 , Mean-squared error = 0.347 , Accuracy = 0.653 , Matthews correlation coefficient = 0.265
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3689
# 	Under-represented class = 1, count = 395
# 	Will proceed by creating balanced training data.
# AUC = 0.647 , F1 score = 0.336 , Mean-squared error = 0.354 , Accuracy = 0.646 , Matthews correlation coefficient = 0.207
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3163
# 	Under-represented class = 1, count = 921
# 	Will proceed by creating balanced training data.
# AUC = 0.655 , F1 score = 0.4 , Mean-squared error = 0.385 , Accuracy = 0.615 , Matthews correlation coefficient = 0.238
# Evaluating with parameters: af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
#     Seed True_Var_Def False_Var_Def  VAF_Lower_Limit  VAF_Upper_Limit  \
# 0     10          [1]        [0.33]              NaN              0.5
# 0     10          [1]  [0.33, 0.67]              NaN              0.5
# 0     10    [1, 0.67]        [0.33]              NaN              0.5
# 0     10          [1]        [0.33]              NaN              0.5
# 0     10          [1]  [0.33, 0.67]              NaN              0.5
# ..   ...          ...           ...              ...              ...
# 0    195          [1]  [0.33, 0.67]              NaN              0.5
# 0    195    [1, 0.67]        [0.33]              NaN              0.5
# 0    195          [1]        [0.33]              NaN              0.5
# 0    195          [1]  [0.33, 0.67]              NaN              0.5
# 0    195    [1, 0.67]        [0.33]              NaN              0.5
#
#    Feature_Category  Num_True_Var_Testing  Num_False_Var_Testing  TP   FP  \
# 0          Moderate                    71                    661  50   93
# 0          Moderate                    71                    725  48  121
# 0          Moderate                   135                    661  83  155
# 0            Strict                    71                    661  54  101
# 0            Strict                    71                    725  53  126
# ..              ...                   ...                    ...  ..  ...
# 0            Strict                    71                    443  51  166
# 0            Strict                    92                    422  72  179
# 0        Exhaustive                    71                    422  52  152
# 0        Exhaustive                    71                    443  46  157
# 0        Exhaustive                    92                    422  66  172
#
#      TN  FN       AUC    MCC  F1_score  Accuracy    MSE
# 0   568  21  0.781765  0.421     0.467     0.844  0.156
# 0   604  23  0.754580  0.355     0.400     0.819  0.181
# 0   506  52  0.690161  0.312     0.445     0.740  0.260
# 0   560  17  0.803882  0.440     0.478     0.839  0.161
# 0   599  18  0.786343  0.391     0.424     0.819  0.181
# ..  ...  ..       ...    ...       ...       ...    ...
# 0   277  20  0.671796  0.240     0.354     0.638  0.362
# 0   243  20  0.679219  0.275     0.420     0.613  0.387
# 0   270  19  0.686102  0.265     0.378     0.653  0.347
# 0   286  25  0.646743  0.207     0.336     0.646  0.354
# 0   250  26  0.654904  0.238     0.400     0.615  0.385
#
# [450 rows x 17 columns]

# %% [markdown]
# ## Performance with results from VCFgenie and with a lower VAF and upper VAF cutoff - <b> <font color='royalblue'> FVM models

# %% [markdown]
# ### Define input and output files

# %%
# The input vcf .csv file
outdir = '../results/'
snv_sbs_file = '../data/SNV_data_with_vcf_genie.csv'
perf_out_file_xgb = outdir + 'performance_FVM.csv'

# %% [markdown]
# ### Define parameter and conditions

# %%
af_lower = [0.01,0.02,0.05,0.1]
af_upper = [0.5]
feature_cat = ['Moderate', 'Strict', 'Exhaustive']
true_var = [[1],[1,0.67]]
false_var = [[0.33], [0.33, 0.67]] # Skip if 0.67 is in both true_var and false_var

# %% [markdown]
# ### Define feature categories as a dictionary

# %%
feat_cat_dict = {'Moderate': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','GQ','MLLD','QUAL','REFB',
                'REVB','SAF','SAR','SRF','SRR','SSSB','STB','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Strict': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','MLLD','QUAL','REFB','REVB','SSSB','VARB', 
                           '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Exhaustive': ['AO','DP','FAO','FDP','FRO','FSAF','FSAR','FSRF','FSRR','FWDB',
                'FXX','GQ','HRUN','LEN','MLLD','QD','QUAL','RBI','REFB','REVB',
                'RO','SAF','SAR','SRF','SRR','SSSB','STB','STBP','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT',
                '3_PRIME_NUCLEOTIDE_CONTEXT']
                }

# %% [markdown]
# ### Generate combinations of conditions

# %%
param_combinations = list(product(af_lower, af_upper, feature_cat, true_var, false_var))
print (param_combinations)
print (f"Total combinations = {len(param_combinations)}")
# Out:
# [(0.01, 0.5, 'Moderate', [1], [0.33]), (0.01, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.01, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.01, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.01, 0.5, 'Strict', [1], [0.33]), (0.01, 0.5, 'Strict', [1], [0.33, 0.67]), (0.01, 0.5, 'Strict', [1, 0.67], [0.33]), (0.01, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.01, 0.5, 'Exhaustive', [1], [0.33]), (0.01, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.01, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.01, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Moderate', [1], [0.33]), (0.02, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.02, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.02, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Strict', [1], [0.33]), (0.02, 0.5, 'Strict', [1], [0.33, 0.67]), (0.02, 0.5, 'Strict', [1, 0.67], [0.33]), (0.02, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.02, 0.5, 'Exhaustive', [1], [0.33]), (0.02, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.02, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.02, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Moderate', [1], [0.33]), (0.05, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.05, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.05, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Strict', [1], [0.33]), (0.05, 0.5, 'Strict', [1], [0.33, 0.67]), (0.05, 0.5, 'Strict', [1, 0.67], [0.33]), (0.05, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.05, 0.5, 'Exhaustive', [1], [0.33]), (0.05, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.05, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.05, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Moderate', [1], [0.33]), (0.1, 0.5, 'Moderate', [1], [0.33, 0.67]), (0.1, 0.5, 'Moderate', [1, 0.67], [0.33]), (0.1, 0.5, 'Moderate', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Strict', [1], [0.33]), (0.1, 0.5, 'Strict', [1], [0.33, 0.67]), (0.1, 0.5, 'Strict', [1, 0.67], [0.33]), (0.1, 0.5, 'Strict', [1, 0.67], [0.33, 0.67]), (0.1, 0.5, 'Exhaustive', [1], [0.33]), (0.1, 0.5, 'Exhaustive', [1], [0.33, 0.67]), (0.1, 0.5, 'Exhaustive', [1, 0.67], [0.33]), (0.1, 0.5, 'Exhaustive', [1, 0.67], [0.33, 0.67])]
# Total combinations = 48

# %% [markdown]
# ### Run Xtreme Gradient Boosting iteratively in these conditions

# %%
df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')

# To eliminate the performance bias due to sampling, we will use a set of seeds to perform
# random sampling. Using just a single seed might bias the testing data sampled
# and a very good performance on just one iteration of testing dataset is highly indicative of
# performance bias.
# In each iteration, 25 samples will be randomly selected for training and 6 for testing.

# Changing to perform 50 iterations
seed_list = [10,20,3247,24,4501,25,79,299,1001,287,497,300,999,6,1,217,21,29,47,187,701,702,703,704,801,802,804,810,101,102,103,104,105,106,121,
             122,123,124,125,127,141,142,143,144,145,191,192,193,194,195]

for seed_i in seed_list:
    # Get all the sample IDs
    all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

    # Set the random sampling seed
    random.seed(seed_i)

    # We will pick 6 samples for testing
    testing_set_samples = random.sample(all_sample_ids, k=6)

    print (f"testing samples = {testing_set_samples}")
    df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
    df_snvs_testing.reset_index(drop=True, inplace=True)
    df_snvs_training.reset_index(drop=True, inplace=True)

    print (f"Running predictions for all parameter/feature combinations with seed {seed_i}...", end="", flush=True)
    df_perf_seed_i = pd.DataFrame()
    for comb_i in param_combinations:
        af_lower_i, af_upper_i, feat_cat_i, true_var_i, false_var_i = comb_i
        print (f"Evaluating with parameters: af_lower_i={af_lower_i}, af_upper_i={af_upper_i}, feat_cat_i={feat_cat_i}, true_var_i={true_var_i}, false_var_i={false_var_i}")

        # If the 2/3 variant is included in both the true variant and false variant
        # then exclude that combination
        if 0.67 in true_var_i and 0.67 in false_var_i:
            continue
        feature_cols = feat_cat_dict[feat_cat_i]

        # Prepare training data for this parameters combination
        df_snvs_training_comb_i = df_snvs_training.copy()
        df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['AF'] > af_lower_i) & 
                                                       (df_snvs_training_comb_i['AF'] < af_upper_i)]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for training
        X = df_snvs_training_comb_i[feature_cols]
        y = df_snvs_training_comb_i[target_cols].tolist()

        # Create balanced datasets
        train_sample, train_index_list = create_balanced_datasets(X,y)

        # Prepare the testing dataset for the current paramters combination
        df_snvs_testing_comb_i = df_snvs_testing.copy()
        df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['AF'] > af_lower_i) & 
                                                       (df_snvs_testing_comb_i['AF'] < af_upper_i)]
        if len(true_var_i) == 1 and len(false_var_i) == 1:
            df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var_i[0]) |
                                                (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var_i[0])]

        df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)
        if len(true_var_i) == 1:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0]) else 0 ))
        else:
            overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if (x == true_var_i[0] or x == true_var_i[1]) else 0 ))

        # Create a binary response column to identify a variant as true variant (1) or false variant (0)
        df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
        target_cols = 'OVERLAP_CATEGORY' # Response column 

        # Define X and y for testing
        X_test = df_snvs_testing_comb_i[feature_cols]
        y_test = df_snvs_testing_comb_i[target_cols].tolist()

        # Train XGB model
        num_jobs = 6
        n_trees = 100
        mdepth = 10
        xgb_model = XGBClassifier(use_label_encoder=False, 
                              booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                              n_estimators=n_trees, # number of trees, default = 100
                              eta=0.2, # this is learning rate, default = 0.3
                              max_depth=mdepth, # maximum depth of the tree, default = 6
                              gamma = 1, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                              reg_lambda = 1, # regularization parameter, defautl = 1
                              eval_metric = 'logloss')
        fpr_tpr = [] # Store all the fpr, tpr values for each model 
        auc_scores = []
        df_y_pred_all_models = pd.DataFrame()
        df_y_scores_all_models = pd.DataFrame()
        df_all_cv_scores = pd.DataFrame()
        df_feature_importances_all_models = pd.DataFrame()
        for model_i in list(train_sample.keys()):
            X_train_model_i = train_sample[model_i]['X_train']
            y_train_model_i = train_sample[model_i]['y_train']
    #         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
            X_train_model_i = X_train_model_i.apply(pd.to_numeric)
            xgb_model.fit(X_train_model_i,y_train_model_i)

            # Predict using model_i on the test data
            y_pred = xgb_model.predict(X_test)
            df_y_pred_all_models[f"Model_{model_i}"] = y_pred
            y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
            df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
            false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
            fpr_tpr.append([false_positive,true_positive])
            # Calculate ROC only if both true and false labels are present.
            # Otherwise, the function roc_auc_score returns error.
            if len(set(y_test)) == 2:
                auc_test = roc_auc_score(y_test, y_pred)
            else:
                auc_test = math.nan
            auc_scores.append(auc_test)
        # Calculate metrics only if y_test has both true and false iSNVs labels.
        # Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
        if len(set(y_test)) == 2:
            # Get the consensus predictions from all models
            y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

            # Calculate metrics on the consensus prediction
            auc_test = roc_auc_score(y_test, y_pred_consensus)

            # Calculate the F1 score
            F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

            # Calculate the mean-squared error
            mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

            # Calculate the accuracy
            accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

            # Calculate the MCC
            mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

            # Print the performance metrics on test data
            # Uncomment to see the metrics for each combination
            print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

            # Get the confusion matrix
            cm = confusion_matrix(y_test, y_pred_consensus)

            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
        else:
            # Get the indices of false positives
            false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true positives
            true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
            # Get the indices of true negatives
            true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
            # Get the indices of false negatives
            false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

            fp = len(false_positive_ind)
            tp = len(true_positive_ind)
            tn = len(true_negative_ind)
            fn = len(false_negative_ind)
            auc_test = math.nan
            mcc_test = math.nan
            F1_score_test = math.nan
            accuracy_test = math.nan
            mse_test = math.nan

        cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
                'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
                'F1_score', 'Accuracy', 'MSE']

        # Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
        df_tmp = pd.DataFrame(data=[[seed_i, true_var_i, false_var_i,af_lower_i,af_upper_i,feat_cat_i, 
                                     tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                                     accuracy_test, mse_test]], columns=cols)
        df_perf_seed_i = df_perf_seed_i.append(df_tmp)
        #break
    df_perf_out_xgb = df_perf_out_xgb.append(df_perf_seed_i)
    print ("Done!")
df_perf_out_xgb.to_csv(perf_out_file_xgb, index=False)
df_perf_out_xgb
# Out:
# testing samples = ['sample24', 'sample5', 'sample10', 'sample15', 'sample1', 'sample31']
# Running predictions for all parameter/feature combinations with seed 10...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.78 , F1 score = 0.439 , Mean-squared error = 0.171 , Accuracy = 0.829 , Matthews correlation coefficient = 0.398
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3404
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.748 , F1 score = 0.386 , Mean-squared error = 0.181 , Accuracy = 0.819 , Matthews correlation coefficient = 0.342
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.673 , F1 score = 0.418 , Mean-squared error = 0.27 , Accuracy = 0.73 , Matthews correlation coefficient = 0.281
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.816 , F1 score = 0.484 , Mean-squared error = 0.155 , Accuracy = 0.845 , Matthews correlation coefficient = 0.453
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3404
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.767 , F1 score = 0.398 , Mean-squared error = 0.183 , Accuracy = 0.817 , Matthews correlation coefficient = 0.362
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.7 , F1 score = 0.453 , Mean-squared error = 0.25 , Accuracy = 0.75 , Matthews correlation coefficient = 0.327
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.783 , F1 score = 0.462 , Mean-squared error = 0.154 , Accuracy = 0.846 , Matthews correlation coefficient = 0.418
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3404
# 	Under-represented class = 1, count = 377
# 	Will proceed by creating balanced training data.
# AUC = 0.751 , F1 score = 0.395 , Mean-squared error = 0.174 , Accuracy = 0.826 , Matthews correlation coefficient = 0.351
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2923
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.661 , F1 score = 0.404 , Mean-squared error = 0.279 , Accuracy = 0.721 , Matthews correlation coefficient = 0.261
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.775 , F1 score = 0.42 , Mean-squared error = 0.168 , Accuracy = 0.832 , Matthews correlation coefficient = 0.383
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.775 , F1 score = 0.389 , Mean-squared error = 0.179 , Accuracy = 0.821 , Matthews correlation coefficient = 0.362
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.66 , F1 score = 0.389 , Mean-squared error = 0.282 , Accuracy = 0.718 , Matthews correlation coefficient = 0.251
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.799 , F1 score = 0.442 , Mean-squared error = 0.163 , Accuracy = 0.837 , Matthews correlation coefficient = 0.414
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.778 , F1 score = 0.383 , Mean-squared error = 0.189 , Accuracy = 0.811 , Matthews correlation coefficient = 0.359
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.668 , F1 score = 0.401 , Mean-squared error = 0.268 , Accuracy = 0.732 , Matthews correlation coefficient = 0.269
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.763 , F1 score = 0.402 , Mean-squared error = 0.176 , Accuracy = 0.824 , Matthews correlation coefficient = 0.362
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 334
# 	Will proceed by creating balanced training data.
# AUC = 0.774 , F1 score = 0.386 , Mean-squared error = 0.182 , Accuracy = 0.818 , Matthews correlation coefficient = 0.359
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2888
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.638 , F1 score = 0.366 , Mean-squared error = 0.283 , Accuracy = 0.717 , Matthews correlation coefficient = 0.221
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.684 , F1 score = 0.532 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.351
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.626 , F1 score = 0.43 , Mean-squared error = 0.317 , Accuracy = 0.683 , Matthews correlation coefficient = 0.226
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.635 , F1 score = 0.532 , Mean-squared error = 0.339 , Accuracy = 0.661 , Matthews correlation coefficient = 0.267
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.682 , F1 score = 0.528 , Mean-squared error = 0.307 , Accuracy = 0.693 , Matthews correlation coefficient = 0.328
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.62 , F1 score = 0.426 , Mean-squared error = 0.358 , Accuracy = 0.642 , Matthews correlation coefficient = 0.207
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.65 , F1 score = 0.563 , Mean-squared error = 0.349 , Accuracy = 0.651 , Matthews correlation coefficient = 0.287
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.701 , F1 score = 0.556 , Mean-squared error = 0.25 , Accuracy = 0.75 , Matthews correlation coefficient = 0.385
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1090
# 	Under-represented class = 1, count = 203
# 	Will proceed by creating balanced training data.
# AUC = 0.631 , F1 score = 0.435 , Mean-squared error = 0.298 , Accuracy = 0.702 , Matthews correlation coefficient = 0.241
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 903
# 	Under-represented class = 1, count = 390
# 	Will proceed by creating balanced training data.
# AUC = 0.656 , F1 score = 0.557 , Mean-squared error = 0.321 , Accuracy = 0.679 , Matthews correlation coefficient = 0.306
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.604 , F1 score = 0.5 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.226
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.574 , F1 score = 0.409 , Mean-squared error = 0.371 , Accuracy = 0.629 , Matthews correlation coefficient = 0.167
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.662 , F1 score = 0.676 , Mean-squared error = 0.343 , Accuracy = 0.657 , Matthews correlation coefficient = 0.322
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.535 , F1 score = 0.435 , Mean-squared error = 0.456 , Accuracy = 0.544 , Matthews correlation coefficient = 0.075
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.543 , F1 score = 0.364 , Mean-squared error = 0.4 , Accuracy = 0.6 , Matthews correlation coefficient = 0.099
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.608 , F1 score = 0.658 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.216
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.607 , F1 score = 0.542 , Mean-squared error = 0.386 , Accuracy = 0.614 , Matthews correlation coefficient = 0.222
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 268
# 	Under-represented class = 1, count = 92
# 	Will proceed by creating balanced training data.
# AUC = 0.592 , F1 score = 0.444 , Mean-squared error = 0.357 , Accuracy = 0.643 , Matthews correlation coefficient = 0.205
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 215
# 	Under-represented class = 1, count = 145
# 	Will proceed by creating balanced training data.
# AUC = 0.646 , F1 score = 0.667 , Mean-squared error = 0.357 , Accuracy = 0.643 , Matthews correlation coefficient = 0.289
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample12', 'sample27', 'sample14', 'sample2', 'sample6', 'sample23']
# Running predictions for all parameter/feature combinations with seed 20...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.79 , F1 score = 0.523 , Mean-squared error = 0.123 , Accuracy = 0.877 , Matthews correlation coefficient = 0.474
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3410
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.773 , F1 score = 0.447 , Mean-squared error = 0.139 , Accuracy = 0.861 , Matthews correlation coefficient = 0.406
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.643 , F1 score = 0.453 , Mean-squared error = 0.268 , Accuracy = 0.732 , Matthews correlation coefficient = 0.277
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.76 , F1 score = 0.488 , Mean-squared error = 0.129 , Accuracy = 0.871 , Matthews correlation coefficient = 0.431
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3410
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.771 , F1 score = 0.457 , Mean-squared error = 0.13 , Accuracy = 0.87 , Matthews correlation coefficient = 0.415
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.654 , F1 score = 0.468 , Mean-squared error = 0.267 , Accuracy = 0.733 , Matthews correlation coefficient = 0.293
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.771 , F1 score = 0.491 , Mean-squared error = 0.133 , Accuracy = 0.867 , Matthews correlation coefficient = 0.438
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3410
# 	Under-represented class = 1, count = 379
# 	Will proceed by creating balanced training data.
# AUC = 0.774 , F1 score = 0.451 , Mean-squared error = 0.136 , Accuracy = 0.864 , Matthews correlation coefficient = 0.411
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2982
# 	Under-represented class = 1, count = 807
# 	Will proceed by creating balanced training data.
# AUC = 0.645 , F1 score = 0.455 , Mean-squared error = 0.265 , Accuracy = 0.735 , Matthews correlation coefficient = 0.281
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.784 , F1 score = 0.491 , Mean-squared error = 0.124 , Accuracy = 0.876 , Matthews correlation coefficient = 0.447
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.768 , F1 score = 0.42 , Mean-squared error = 0.137 , Accuracy = 0.863 , Matthews correlation coefficient = 0.386
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.617 , F1 score = 0.408 , Mean-squared error = 0.285 , Accuracy = 0.715 , Matthews correlation coefficient = 0.223
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.756 , F1 score = 0.453 , Mean-squared error = 0.133 , Accuracy = 0.867 , Matthews correlation coefficient = 0.402
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.725 , F1 score = 0.377 , Mean-squared error = 0.142 , Accuracy = 0.858 , Matthews correlation coefficient = 0.331
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.636 , F1 score = 0.436 , Mean-squared error = 0.283 , Accuracy = 0.717 , Matthews correlation coefficient = 0.253
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.764 , F1 score = 0.46 , Mean-squared error = 0.133 , Accuracy = 0.867 , Matthews correlation coefficient = 0.411
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3361
# 	Under-represented class = 1, count = 337
# 	Will proceed by creating balanced training data.
# AUC = 0.758 , F1 score = 0.409 , Mean-squared error = 0.14 , Accuracy = 0.86 , Matthews correlation coefficient = 0.372
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2942
# 	Under-represented class = 1, count = 756
# 	Will proceed by creating balanced training data.
# AUC = 0.631 , F1 score = 0.427 , Mean-squared error = 0.273 , Accuracy = 0.727 , Matthews correlation coefficient = 0.25
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.678 , F1 score = 0.571 , Mean-squared error = 0.297 , Accuracy = 0.703 , Matthews correlation coefficient = 0.347
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.693 , F1 score = 0.541 , Mean-squared error = 0.266 , Accuracy = 0.734 , Matthews correlation coefficient = 0.361
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.599 , F1 score = 0.564 , Mean-squared error = 0.398 , Accuracy = 0.602 , Matthews correlation coefficient = 0.198
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.73 , F1 score = 0.638 , Mean-squared error = 0.248 , Accuracy = 0.752 , Matthews correlation coefficient = 0.451
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.723 , F1 score = 0.579 , Mean-squared error = 0.25 , Accuracy = 0.75 , Matthews correlation coefficient = 0.413
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.582 , F1 score = 0.539 , Mean-squared error = 0.414 , Accuracy = 0.586 , Matthews correlation coefficient = 0.165
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.701 , F1 score = 0.603 , Mean-squared error = 0.287 , Accuracy = 0.713 , Matthews correlation coefficient = 0.385
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1163
# 	Under-represented class = 1, count = 220
# 	Will proceed by creating balanced training data.
# AUC = 0.677 , F1 score = 0.519 , Mean-squared error = 0.289 , Accuracy = 0.711 , Matthews correlation coefficient = 0.326
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 977
# 	Under-represented class = 1, count = 406
# 	Will proceed by creating balanced training data.
# AUC = 0.621 , F1 score = 0.579 , Mean-squared error = 0.375 , Accuracy = 0.625 , Matthews correlation coefficient = 0.244
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.771 , F1 score = 0.7 , Mean-squared error = 0.207 , Accuracy = 0.793 , Matthews correlation coefficient = 0.542
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.746 , F1 score = 0.632 , Mean-squared error = 0.184 , Accuracy = 0.816 , Matthews correlation coefficient = 0.51
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.447 , F1 score = 0.4 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = -0.107
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.645 , F1 score = 0.526 , Mean-squared error = 0.31 , Accuracy = 0.69 , Matthews correlation coefficient = 0.297
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.729 , F1 score = 0.6 , Mean-squared error = 0.211 , Accuracy = 0.789 , Matthews correlation coefficient = 0.457
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.447 , F1 score = 0.364 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = -0.109
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.668 , F1 score = 0.571 , Mean-squared error = 0.31 , Accuracy = 0.69 , Matthews correlation coefficient = 0.33
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 283
# 	Under-represented class = 1, count = 109
# 	Will proceed by creating balanced training data.
# AUC = 0.729 , F1 score = 0.6 , Mean-squared error = 0.211 , Accuracy = 0.789 , Matthews correlation coefficient = 0.457
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 226
# 	Under-represented class = 1, count = 166
# 	Will proceed by creating balanced training data.
# AUC = 0.5 , F1 score = 0.457 , Mean-squared error = 0.5 , Accuracy = 0.5 , Matthews correlation coefficient = 0.0
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
# testing samples = ['sample6', 'sample25', 'sample4', 'sample10', 'sample20', 'sample26']
# Running predictions for all parameter/feature combinations with seed 3247...Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.63 , F1 score = 0.336 , Mean-squared error = 0.166 , Accuracy = 0.834 , Matthews correlation coefficient = 0.243
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2259
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.63 , F1 score = 0.302 , Mean-squared error = 0.181 , Accuracy = 0.819 , Matthews correlation coefficient = 0.212
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 495
# 	Will proceed by creating balanced training data.
# AUC = 0.577 , F1 score = 0.356 , Mean-squared error = 0.308 , Accuracy = 0.692 , Matthews correlation coefficient = 0.154
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.621 , F1 score = 0.319 , Mean-squared error = 0.175 , Accuracy = 0.825 , Matthews correlation coefficient = 0.221
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2259
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.612 , F1 score = 0.276 , Mean-squared error = 0.19 , Accuracy = 0.81 , Matthews correlation coefficient = 0.181
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 495
# 	Will proceed by creating balanced training data.
# AUC = 0.585 , F1 score = 0.371 , Mean-squared error = 0.311 , Accuracy = 0.689 , Matthews correlation coefficient = 0.165
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.622 , F1 score = 0.323 , Mean-squared error = 0.166 , Accuracy = 0.834 , Matthews correlation coefficient = 0.23
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2259
# 	Under-represented class = 1, count = 240
# 	Will proceed by creating balanced training data.
# AUC = 0.617 , F1 score = 0.284 , Mean-squared error = 0.182 , Accuracy = 0.818 , Matthews correlation coefficient = 0.192
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2004
# 	Under-represented class = 1, count = 495
# 	Will proceed by creating balanced training data.
# AUC = 0.57 , F1 score = 0.339 , Mean-squared error = 0.301 , Accuracy = 0.699 , Matthews correlation coefficient = 0.145
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.626 , F1 score = 0.313 , Mean-squared error = 0.193 , Accuracy = 0.807 , Matthews correlation coefficient = 0.212
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2206
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.624 , F1 score = 0.281 , Mean-squared error = 0.199 , Accuracy = 0.801 , Matthews correlation coefficient = 0.189
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.564 , F1 score = 0.338 , Mean-squared error = 0.322 , Accuracy = 0.678 , Matthews correlation coefficient = 0.126
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.623 , F1 score = 0.308 , Mean-squared error = 0.195 , Accuracy = 0.805 , Matthews correlation coefficient = 0.206
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2206
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.631 , F1 score = 0.285 , Mean-squared error = 0.207 , Accuracy = 0.793 , Matthews correlation coefficient = 0.195
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.573 , F1 score = 0.357 , Mean-squared error = 0.332 , Accuracy = 0.668 , Matthews correlation coefficient = 0.137
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.641 , F1 score = 0.335 , Mean-squared error = 0.186 , Accuracy = 0.814 , Matthews correlation coefficient = 0.238
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 2206
# 	Under-represented class = 1, count = 197
# 	Will proceed by creating balanced training data.
# AUC = 0.626 , F1 score = 0.283 , Mean-squared error = 0.199 , Accuracy = 0.801 , Matthews correlation coefficient = 0.193
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1960
# 	Under-represented class = 1, count = 443
# 	Will proceed by creating balanced training data.
# AUC = 0.557 , F1 score = 0.326 , Mean-squared error = 0.325 , Accuracy = 0.675 , Matthews correlation coefficient = 0.112
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.538 , F1 score = 0.262 , Mean-squared error = 0.293 , Accuracy = 0.707 , Matthews correlation coefficient = 0.087
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.56 , F1 score = 0.293 , Mean-squared error = 0.283 , Accuracy = 0.717 , Matthews correlation coefficient = 0.117
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.52 , F1 score = 0.347 , Mean-squared error = 0.424 , Accuracy = 0.576 , Matthews correlation coefficient = 0.042
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.501 , F1 score = 0.207 , Mean-squared error = 0.332 , Accuracy = 0.668 , Matthews correlation coefficient = 0.001
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.528 , F1 score = 0.243 , Mean-squared error = 0.303 , Accuracy = 0.697 , Matthews correlation coefficient = 0.054
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.507 , F1 score = 0.317 , Mean-squared error = 0.431 , Accuracy = 0.569 , Matthews correlation coefficient = 0.015
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.529 , F1 score = 0.249 , Mean-squared error = 0.304 , Accuracy = 0.696 , Matthews correlation coefficient = 0.065
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 692
# 	Under-represented class = 1, count = 119
# 	Will proceed by creating balanced training data.
# AUC = 0.544 , F1 score = 0.271 , Mean-squared error = 0.3 , Accuracy = 0.7 , Matthews correlation coefficient = 0.083
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 603
# 	Under-represented class = 1, count = 208
# 	Will proceed by creating balanced training data.
# AUC = 0.504 , F1 score = 0.318 , Mean-squared error = 0.436 , Accuracy = 0.564 , Matthews correlation coefficient = 0.009
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 175
# 	Under-represented class = 1, count = 52
# 	Will proceed by creating balanced training data.
# AUC = 0.438 , F1 score = 0.174 , Mean-squared error = 0.555 , Accuracy = 0.445 , Matthews correlation coefficient = -0.16
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# ...
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3162
# 	Under-represented class = 1, count = 904
# 	Will proceed by creating balanced training data.
# AUC = 0.661 , F1 score = 0.389 , Mean-squared error = 0.385 , Accuracy = 0.615 , Matthews correlation coefficient = 0.241
# Evaluating with parameters: af_lower_i=0.01, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.641 , F1 score = 0.279 , Mean-squared error = 0.359 , Accuracy = 0.641 , Matthews correlation coefficient = 0.18
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.609 , F1 score = 0.248 , Mean-squared error = 0.367 , Accuracy = 0.633 , Matthews correlation coefficient = 0.137
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.633 , F1 score = 0.33 , Mean-squared error = 0.39 , Accuracy = 0.61 , Matthews correlation coefficient = 0.189
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.636 , F1 score = 0.273 , Mean-squared error = 0.383 , Accuracy = 0.617 , Matthews correlation coefficient = 0.172
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.609 , F1 score = 0.246 , Mean-squared error = 0.384 , Accuracy = 0.616 , Matthews correlation coefficient = 0.136
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.651 , F1 score = 0.344 , Mean-squared error = 0.39 , Accuracy = 0.61 , Matthews correlation coefficient = 0.214
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.642 , F1 score = 0.281 , Mean-squared error = 0.357 , Accuracy = 0.643 , Matthews correlation coefficient = 0.181
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3640
# 	Under-represented class = 1, count = 345
# 	Will proceed by creating balanced training data.
# AUC = 0.617 , F1 score = 0.253 , Mean-squared error = 0.37 , Accuracy = 0.63 , Matthews correlation coefficient = 0.147
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3127
# 	Under-represented class = 1, count = 858
# 	Will proceed by creating balanced training data.
# AUC = 0.631 , F1 score = 0.327 , Mean-squared error = 0.395 , Accuracy = 0.605 , Matthews correlation coefficient = 0.185
# Evaluating with parameters: af_lower_i=0.02, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.419 , F1 score = 0.199 , Mean-squared error = 0.614 , Accuracy = 0.386 , Matthews correlation coefficient = -0.122
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.411 , F1 score = 0.183 , Mean-squared error = 0.607 , Accuracy = 0.393 , Matthews correlation coefficient = -0.131
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.508 , F1 score = 0.308 , Mean-squared error = 0.568 , Accuracy = 0.432 , Matthews correlation coefficient = 0.013
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.485 , F1 score = 0.247 , Mean-squared error = 0.589 , Accuracy = 0.411 , Matthews correlation coefficient = -0.023
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.485 , F1 score = 0.235 , Mean-squared error = 0.568 , Accuracy = 0.432 , Matthews correlation coefficient = -0.022
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.545 , F1 score = 0.337 , Mean-squared error = 0.553 , Accuracy = 0.447 , Matthews correlation coefficient = 0.074
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.429 , F1 score = 0.208 , Mean-squared error = 0.619 , Accuracy = 0.381 , Matthews correlation coefficient = -0.108
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 1084
# 	Under-represented class = 1, count = 221
# 	Will proceed by creating balanced training data.
# AUC = 0.421 , F1 score = 0.192 , Mean-squared error = 0.612 , Accuracy = 0.388 , Matthews correlation coefficient = -0.117
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 880
# 	Under-represented class = 1, count = 425
# 	Will proceed by creating balanced training data.
# AUC = 0.514 , F1 score = 0.314 , Mean-squared error = 0.573 , Accuracy = 0.427 , Matthews correlation coefficient = 0.023
# Evaluating with parameters: af_lower_i=0.05, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.436 , F1 score = 0.111 , Mean-squared error = 0.571 , Accuracy = 0.429 , Matthews correlation coefficient = -0.07
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.369 , F1 score = 0.078 , Mean-squared error = 0.602 , Accuracy = 0.398 , Matthews correlation coefficient = -0.141
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.523 , F1 score = 0.222 , Mean-squared error = 0.534 , Accuracy = 0.466 , Matthews correlation coefficient = 0.031
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Moderate, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.397 , F1 score = 0.1 , Mean-squared error = 0.643 , Accuracy = 0.357 , Matthews correlation coefficient = -0.116
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.276 , F1 score = 0.048 , Mean-squared error = 0.678 , Accuracy = 0.322 , Matthews correlation coefficient = -0.247
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.514 , F1 score = 0.217 , Mean-squared error = 0.551 , Accuracy = 0.449 , Matthews correlation coefficient = 0.018
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Strict, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 142
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.421 , F1 score = 0.107 , Mean-squared error = 0.598 , Accuracy = 0.402 , Matthews correlation coefficient = -0.087
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1], false_var_i=[0.33, 0.67]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 202
# 	Under-represented class = 1, count = 110
# 	Will proceed by creating balanced training data.
# AUC = 0.391 , F1 score = 0.083 , Mean-squared error = 0.559 , Accuracy = 0.441 , Matthews correlation coefficient = -0.116
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33]
# 	Train-test split resulted in imbalanced training data
# 	Over-represented class = 1, count = 170
# 	Under-represented class = 0, count = 142
# 	Will proceed by creating balanced training data.
# AUC = 0.542 , F1 score = 0.235 , Mean-squared error = 0.551 , Accuracy = 0.449 , Matthews correlation coefficient = 0.057
# Evaluating with parameters: af_lower_i=0.1, af_upper_i=0.5, feat_cat_i=Exhaustive, true_var_i=[1, 0.67], false_var_i=[0.33, 0.67]
# Done!
#     Seed True_Var_Def False_Var_Def  VAF_Lower_Limit  VAF_Upper_Limit  \
# 0     10          [1]        [0.33]             0.01              0.5
# 0     10          [1]  [0.33, 0.67]             0.01              0.5
# 0     10    [1, 0.67]        [0.33]             0.01              0.5
# 0     10          [1]        [0.33]             0.01              0.5
# 0     10          [1]  [0.33, 0.67]             0.01              0.5
# ..   ...          ...           ...              ...              ...
# 0    195          [1]  [0.33, 0.67]             0.10              0.5
# 0    195    [1, 0.67]        [0.33]             0.10              0.5
# 0    195          [1]        [0.33]             0.10              0.5
# 0    195          [1]  [0.33, 0.67]             0.10              0.5
# 0    195    [1, 0.67]        [0.33]             0.10              0.5
#
#    Feature_Category  Num_True_Var_Testing  Num_False_Var_Testing  TP   FP  \
# 0          Moderate                    68                    661  49  106
# 0          Moderate                    68                    724  45  120
# 0          Moderate                   131                    661  77  160
# 0            Strict                    68                    661  53   98
# 0            Strict                    68                    724  48  125
# ..              ...                   ...                    ...  ..  ...
# 0            Strict                     9                    109   2   73
# 0            Strict                    15                    103   9   59
# 0        Exhaustive                     9                    103   4   62
# 0        Exhaustive                     9                    109   3   60
# 0        Exhaustive                    15                    103  10   60
#
#      TN  FN       AUC    MCC  F1_score  Accuracy    MSE
# 0   555  19  0.780113  0.398     0.439     0.829  0.171
# 0   604  23  0.748009  0.342     0.386     0.819  0.181
# 0   501  54  0.672864  0.281     0.418     0.730  0.270
# 0   563  15  0.815576  0.453     0.484     0.845  0.155
# 0   599  20  0.766615  0.362     0.398     0.817  0.183
# ..  ...  ..       ...    ...       ...       ...    ...
# 0    36   7  0.276249 -0.247     0.048     0.322  0.678
# 0    44   6  0.513592  0.018     0.217     0.449  0.551
# 0    41   5  0.421251 -0.087     0.107     0.402  0.598
# 0    49   6  0.391437 -0.116     0.083     0.441  0.559
# 0    43   5  0.542071  0.057     0.235     0.449  0.551
#
# [1800 rows x 17 columns]

# %% [markdown]
# ## Calculate the cumulative performance metrics for each model separately

# %%
inputdir = '../results/'
outdir = '../results/cumulative_perf_metrics/'
Path(outdir).mkdir(parents=True, exist_ok=True)

file_list = glob.glob(inputdir + '/performance*')
print (file_list)
for file_i in file_list:
    infile_name = file_i.split('/')[-1]
    outfile = outdir + infile_name
    # Read the file
    df_file_i = pd.read_csv(file_i)
    
    # First, get the distinct parameter combinations in this file. 
    # We will do this by choosing all the rows for a single seed. 
    seed_val = 10
    df_param_uniq = df_file_i.copy()
    df_param_uniq = df_param_uniq.loc[(df_param_uniq['Seed'] == seed_val)]
    df_param_uniq.reset_index(drop=True, inplace=True)    
    
    # Now iterate over the rows of df_param_uniq and get the performance
    # metrics for each row across all the 10 seeds.
    df_cumul_perf = pd.DataFrame()
    for idx_i, row_i in df_param_uniq.iterrows():
        tv_def, fv_def, vaf_up, feat_cat = row_i['True_Var_Def'], row_i['False_Var_Def'], row_i['VAF_Upper_Limit'], row_i['Feature_Category']
        if 'VAF_Lower_Limit' in row_i.to_frame().transpose().columns and not math.isnan(row_i['VAF_Lower_Limit']):
            vaf_low = row_i['VAF_Lower_Limit']
        else:
            vaf_low = ''
        df_comb_i_all_perf = df_file_i.copy()
        if vaf_low:
            df_comb_i_all_perf = df_comb_i_all_perf.loc[(df_comb_i_all_perf['True_Var_Def'] == tv_def) &
                                                        (df_comb_i_all_perf['False_Var_Def'] == fv_def) &
                                                        (df_comb_i_all_perf['VAF_Lower_Limit'] == vaf_low) &
                                                        (df_comb_i_all_perf['VAF_Upper_Limit'] == vaf_up) &
                                                        (df_comb_i_all_perf['Feature_Category'] == feat_cat)]
        else:
            df_comb_i_all_perf = df_comb_i_all_perf.loc[(df_comb_i_all_perf['True_Var_Def'] == tv_def) &
                                                        (df_comb_i_all_perf['False_Var_Def'] == fv_def) &
                                                        (df_comb_i_all_perf['VAF_Upper_Limit'] == vaf_up) &
                                                        (df_comb_i_all_perf['Feature_Category'] == feat_cat)]
        df_comb_i_all_perf.reset_index(drop=True, inplace=True)
        # Get the cumulative performance metrics and also the counts
        num_tv, num_fv, tp, fp, tn, fn, auc, mcc, f1_score, acc, mse = df_comb_i_all_perf[['Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC',
                                                  'F1_score', 'Accuracy', 'MSE']].median()
        df_tmp_i = pd.DataFrame(data =[[tv_def, fv_def, vaf_low, vaf_up, feat_cat, round(num_tv), round(num_fv), round(tp), round(fp),
                                        round(tn), round(fn), auc, mcc, f1_score, acc, mse]],
                                columns = ['True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit', 
                                           'Feature_Category', 'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 
                                           'FP', 'TN', 'FN', 'AUC', 'MCC', 'F1_score', 'Accuracy', 'MSE'])
        df_cumul_perf = df_cumul_perf.append(df_tmp_i)
    df_cumul_perf.reset_index(drop=True, inplace=True)
    df_cumul_perf.to_csv(outfile, index=False)
# Out:
# ['../results/performance_FM.csv', '../results/performance_FVM.csv', '../results/performance_VM.csv']

# %% [markdown]
# ## Save the best performing models for each prediction strategy

# %% [markdown]
# For FM, VM and FVM prediction strategies, save the models corresponding to the optimum parameter/feature combination and the optimum hyperparameters that result in best performance over the 50 iterations of random training/testing.

# %%
feat_cat_dict = {'Moderate': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','GQ','MLLD','QUAL','REFB',
                'REVB','SAF','SAR','SRF','SRR','SSSB','STB','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Strict': ['FSAF','FSAR','FSRF','FSRR','FWDB','FXX','MLLD','QUAL','REFB','REVB','SSSB','VARB', 
                           '5_PRIME_NUCLEOTIDE_CONTEXT', '3_PRIME_NUCLEOTIDE_CONTEXT'],
                'Exhaustive': ['AO','DP','FAO','FDP','FRO','FSAF','FSAR','FSRF','FSRR','FWDB',
                'FXX','GQ','HRUN','LEN','MLLD','QD','QUAL','RBI','REFB','REVB',
                'RO','SAF','SAR','SRF','SRR','SSSB','STB','STBP','VARB', '5_PRIME_NUCLEOTIDE_CONTEXT',
                '3_PRIME_NUCLEOTIDE_CONTEXT']
                }

# %% [markdown]
# ### Save models for FM strategy

# %%
model_dir = '../FM_models/'
Path(model_dir).mkdir(parents=True, exist_ok=True)

# The input vcf .csv file
snv_sbs_file = '../data/SNV_data_wo_vcf_genie.csv'

af_lower = 0.01
af_upper = 0.5 # Updated to only consider a single, strict upper VAF limit of 50%.
                 # Any SNV with VAF > 50% is a major variant and will be excluded.
                 # We will only consider SNVs with VAF < 50%.
feature_cat = 'Strict'
true_var = [1]
false_var = [0.33]

df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

# We will consider the SNVs in each replicate set only once and perform
# training and testing for each replicate set independently.
df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')


seed_i = 252 # The seed corresponding to the train/test iteration of hyperparameter tuning that
             # resulted in best performance.

# Get all the sample IDs
all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

# Set the random sampling seed
random.seed(seed_i)

# We will pick 6 testing samples and make sure snvs from these samples
# are not included in the training set.
testing_set_samples = random.sample(all_sample_ids, k=6)
print (f"testing samples = {testing_set_samples}")
df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_testing.reset_index(drop=True, inplace=True)
df_snvs_training.reset_index(drop=True, inplace=True)

print (f"Running predictions for all parameter/feature combinations with seed {seed_i} ...", end="", flush=True)
feature_cols = feat_cat_dict[feature_cat]

# Prepare training data for this parameters combination
df_snvs_training_comb_i = df_snvs_training.copy()
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['AF'] > af_lower) & 
                                                      (df_snvs_training_comb_i['AF'] < af_upper)]
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                      (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for training
X = df_snvs_training_comb_i[feature_cols]
y = df_snvs_training_comb_i[target_cols].tolist()

# Create balanced datasets
train_sample, train_index_list = create_balanced_datasets(X,y)

# Prepare the testing dataset for the current paramters combination
df_snvs_testing_comb_i = df_snvs_testing.copy()
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['AF'] > af_lower) & 
                                               (df_snvs_testing_comb_i['AF'] < af_upper)]
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                    (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))
df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for testing
X_test = df_snvs_testing_comb_i[feature_cols]
y_test = df_snvs_testing_comb_i[target_cols].tolist()

# Train XGB model with optimum model hyperparameters
eta_opt = 0.3
num_trees_opt = 150
gamma_opt = 1
max_depth_opt = 6
subsample_opt = 1
colsample_opt = 0.5
reg_lambda_opt = 1
reg_alpha_opt = 0

xgb_model = XGBClassifier(use_label_encoder=False, 
                      booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                      n_estimators=num_trees_opt, # number of trees, default = 100
                      eta=eta_opt, # this is learning rate, default = 0.3
                      max_depth=max_depth_opt, # maximum depth of the tree, default = 6
                      gamma = gamma_opt, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                      reg_lambda = reg_lambda_opt, # regularization parameter, defautl = 1
                      eval_metric = 'logloss',
                      colsample_bytree = colsample_opt,
                      alpha = reg_alpha_opt,
                      subsample = subsample_opt)
fpr_tpr = [] # Store all the fpr, tpr values for each model 
auc_scores = []
df_y_pred_all_models = pd.DataFrame()
df_y_scores_all_models = pd.DataFrame()
df_all_cv_scores = pd.DataFrame()
df_feature_importances_all_models = pd.DataFrame()
for model_i in list(train_sample.keys()):
    X_train_model_i = train_sample[model_i]['X_train']
    y_train_model_i = train_sample[model_i]['y_train']
#         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
    X_train_model_i = X_train_model_i.apply(pd.to_numeric)
    xgb_model.fit(X_train_model_i,y_train_model_i)

    # Predict using model_i on the test data
    y_pred = xgb_model.predict(X_test)
    df_y_pred_all_models[f"Model_{model_i}"] = y_pred
    y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
    df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
    false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
    fpr_tpr.append([false_positive,true_positive])
    # Calculate ROC only if both true and false labels are present.
    # Otherwise, the function roc_auc_score returns error.
    if len(set(y_test)) == 2:
        auc_test = roc_auc_score(y_test, y_pred)
    else:
        auc_test = math.nan
    auc_scores.append(auc_test)
    
    # Save the model with joblib
    joblib.dump(xgb_model, model_dir + "_".join(["xgb_model", str(model_i)]))  
# Calculate metrics only if y_test has both true and false iSNVs labels.
# Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
if len(set(y_test)) == 2:
    # Get the consensus predictions from all models
    y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

    # Calculate metrics on the consensus prediction
    auc_test = roc_auc_score(y_test, y_pred_consensus)

    # Calculate the F1 score
    F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

    # Calculate the mean-squared error
    mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

    # Calculate the accuracy
    accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

    # Calculate the MCC
    mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

    # Print the performance metrics on test data
    # Uncomment to see the metrics for each combination
    print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

    # Get the confusion matrix
    cm = confusion_matrix(y_test, y_pred_consensus)

    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
else:
    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
    auc_test = math.nan
    mcc_test = math.nan
    F1_score_test = math.nan
    accuracy_test = math.nan
    mse_test = math.nan

cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
        'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
        'F1_score', 'Accuracy', 'MSE']

# Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
df_tmp = pd.DataFrame(data=[[seed_i, true_var, false_var,af_lower,af_upper,feature_cat, 
                             tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                             accuracy_test, mse_test]], columns=cols)
# Out:
# testing samples = ['sample6', 'sample21', 'sample31', 'sample14', 'sample7', 'sample29']
# Running predictions for all parameter/feature combinations with seed 252 ...	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3385
# 	Under-represented class = 1, count = 402
# 	Will proceed by creating balanced training data.
# AUC = 0.873 , F1 score = 0.735 , Mean-squared error = 0.104 , Accuracy = 0.896 , Matthews correlation coefficient = 0.679

# %%
df_tmp
# Out:
#    Seed True_Var_Def False_Var_Def  VAF_Lower_Limit  VAF_Upper_Limit  \
# 0   252          [1]        [0.33]             0.01              0.5
#
#   Feature_Category  Num_True_Var_Testing  Num_False_Var_Testing  TP  FP   TN  \
# 0           Strict                    43                    207  36  19  188
#
#    FN       AUC    MCC  F1_score  Accuracy    MSE
# 0   7  0.872711  0.679     0.735     0.896  0.104

# %% [markdown]
# ### Save models for VM strategy

# %%
model_dir = '../VM_models/'
Path(model_dir).mkdir(parents=True, exist_ok=True)

# The input vcf .csv file
snv_sbs_file = '../data/SNV_data_with_vcf_genie.csv'

af_upper = 0.5 # Updated to only consider a single, strict upper VAF limit of 50%.
                 # Any SNV with VAF > 50% is a major variant and will be excluded.
                 # We will only consider SNVs with VAF < 50%.
feature_cat = 'Moderate'
true_var = [1]
false_var = [0.33]

df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

# We will consider the SNVs in each replicate set only once and perform
# training and testing for each replicate set independently.
df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')


seed_i = 252 # The seed corresponding to the train/test iteration of hyperparameter tuning that
             # resulted in best performance.

# Randomly select 6 samples for testing 
# Get all the sample IDs
all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

# Set the random sampling seed
random.seed(seed_i)

# We will pick 6 testing samples 
testing_set_samples = random.sample(all_sample_ids, k=6)
print (f"testing samples = {testing_set_samples}")
df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_testing.reset_index(drop=True, inplace=True)
df_snvs_training.reset_index(drop=True, inplace=True)

print (f"Running predictions for all parameter/feature combinations with seed {seed_i} ...", end="", flush=True)
feature_cols = feat_cat_dict[feature_cat]

# Prepare training data for this parameters combination
df_snvs_training_comb_i = df_snvs_training.copy()
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['AF'] < af_upper)]
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                      (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for training
X = df_snvs_training_comb_i[feature_cols]
y = df_snvs_training_comb_i[target_cols].tolist()

# Create balanced datasets
train_sample, train_index_list = create_balanced_datasets(X,y)

# Prepare the testing dataset for the current paramters combination
df_snvs_testing_comb_i = df_snvs_testing.copy()
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['AF'] < af_upper)]
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                    (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))
df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for testing
X_test = df_snvs_testing_comb_i[feature_cols]
y_test = df_snvs_testing_comb_i[target_cols].tolist()

# Train XGB model with optimum model hyperparameters
eta_opt = 0.2
num_trees_opt = 50
gamma_opt = 0
max_depth_opt = 10
subsample_opt = 1
colsample_opt = 0.5
reg_lambda_opt = 2
reg_alpha_opt = 1

xgb_model = XGBClassifier(use_label_encoder=False, 
                      booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                      n_estimators=num_trees_opt, # number of trees, default = 100
                      eta=eta_opt, # this is learning rate, default = 0.3
                      max_depth=max_depth_opt, # maximum depth of the tree, default = 6
                      gamma = gamma_opt, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                      reg_lambda = reg_lambda_opt, # regularization parameter, defautl = 1
                      eval_metric = 'logloss',
                      colsample_bytree = colsample_opt,
                      alpha = reg_alpha_opt,
                      subsample = subsample_opt)
fpr_tpr = [] # Store all the fpr, tpr values for each model 
auc_scores = []
df_y_pred_all_models = pd.DataFrame()
df_y_scores_all_models = pd.DataFrame()
df_all_cv_scores = pd.DataFrame()
df_feature_importances_all_models = pd.DataFrame()
for model_i in list(train_sample.keys()):
    X_train_model_i = train_sample[model_i]['X_train']
    y_train_model_i = train_sample[model_i]['y_train']
#         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
    X_train_model_i = X_train_model_i.apply(pd.to_numeric)
    xgb_model.fit(X_train_model_i,y_train_model_i)

    # Predict using model_i on the test data
    y_pred = xgb_model.predict(X_test)
    df_y_pred_all_models[f"Model_{model_i}"] = y_pred
    y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
    df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
    false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
    fpr_tpr.append([false_positive,true_positive])
    # Calculate ROC only if both true and false labels are present.
    # Otherwise, the function roc_auc_score returns error.
    if len(set(y_test)) == 2:
        auc_test = roc_auc_score(y_test, y_pred)
    else:
        auc_test = math.nan
    auc_scores.append(auc_test)
    
    # Save the model with joblib
    joblib.dump(xgb_model, model_dir + "_".join(["xgb_model", str(model_i)]))  
# Calculate metrics only if y_test has both true and false iSNVs labels.
# Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
if len(set(y_test)) == 2:
    # Get the consensus predictions from all models
    y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

    # Calculate metrics on the consensus prediction
    auc_test = roc_auc_score(y_test, y_pred_consensus)

    # Calculate the F1 score
    F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

    # Calculate the mean-squared error
    mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

    # Calculate the accuracy
    accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

    # Calculate the MCC
    mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

    # Print the performance metrics on test data
    # Uncomment to see the metrics for each combination
    print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

    # Get the confusion matrix
    cm = confusion_matrix(y_test, y_pred_consensus)

    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
else:
    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
    auc_test = math.nan
    mcc_test = math.nan
    F1_score_test = math.nan
    accuracy_test = math.nan
    mse_test = math.nan

cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
        'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
        'F1_score', 'Accuracy', 'MSE']

# Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
df_tmp = pd.DataFrame(data=[[seed_i, true_var, false_var,af_lower,af_upper,feature_cat, 
                             tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                             accuracy_test, mse_test]], columns=cols)
# Out:
# testing samples = ['sample6', 'sample21', 'sample31', 'sample14', 'sample7', 'sample29']
# Running predictions for all parameter/feature combinations with seed 252 ...	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3378
# 	Under-represented class = 1, count = 419
# 	Will proceed by creating balanced training data.
# AUC = 0.865 , F1 score = 0.771 , Mean-squared error = 0.087 , Accuracy = 0.913 , Matthews correlation coefficient = 0.718

# %% [markdown]
# ### Save models for FVM strategy

# %%
model_dir = '../FVM_models/'
Path(model_dir).mkdir(parents=True, exist_ok=True)

# The input vcf .csv file
snv_sbs_file = '../data/SNV_data_with_vcf_genie.csv'

af_lower = 0.01
af_upper = 0.5 # Updated to only consider a single, strict upper VAF limit of 50%.
                 # Any SNV with VAF > 50% is a major variant and will be excluded.
                 # We will only consider SNVs with VAF < 50%.
feature_cat = 'Strict'
true_var = [1]
false_var = [0.33]

df_snv_sbs = pd.read_csv(snv_sbs_file)

# Create a column to include the sample id (excluding the well id)
df_snv_sbs['sample_id'] = df_snv_sbs['sample'].apply(lambda x: x.split('_')[0])

# We will consider the SNVs in each replicate set only once and perform
# training and testing for each replicate set independently.
df_perf_out_xgb = pd.DataFrame()

# Remove variants with FAO = 0
fao_cutoff = 1
df_snv_sbs_fao_filtered = remove_low_coverage_samples(df_snv_sbs, fao_cutoff, 'FAO')


seed_i = 252 # The seed corresponding to the train/test iteration of hyperparameter tuning that
             # resulted in best performance.

# Randomly select 6 samples for testing 
# Get all the sample IDs
all_sample_ids = df_snv_sbs_fao_filtered['sample_id'].drop_duplicates().tolist()

# Set the random sampling seed
random.seed(seed_i)

# We will pick 6 testing samples 
testing_set_samples = random.sample(all_sample_ids, k=6)
print (f"testing samples = {testing_set_samples}")
df_snvs_testing = df_snv_sbs_fao_filtered.loc[df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_training = df_snv_sbs_fao_filtered.loc[~df_snv_sbs_fao_filtered['sample_id'].isin(testing_set_samples)]
df_snvs_testing.reset_index(drop=True, inplace=True)
df_snvs_training.reset_index(drop=True, inplace=True)

print (f"Running predictions for all parameter/feature combinations with seed {seed_i} ...", end="", flush=True)
feature_cols = feat_cat_dict[feature_cat]

# Prepare training data for this parameters combination
df_snvs_training_comb_i = df_snvs_training.copy()
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['AF'] > af_lower) & 
                                                      (df_snvs_training_comb_i['AF'] < af_upper)]
df_snvs_training_comb_i = df_snvs_training_comb_i.loc[(df_snvs_training_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                      (df_snvs_training_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_training_comb_i.reset_index(drop=True, inplace=True)
overlap_cat = list(df_snvs_training_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
df_snvs_training_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for training
X = df_snvs_training_comb_i[feature_cols]
y = df_snvs_training_comb_i[target_cols].tolist()

# Create balanced datasets
train_sample, train_index_list = create_balanced_datasets(X,y)

# Prepare the testing dataset for the current paramters combination
df_snvs_testing_comb_i = df_snvs_testing.copy()
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['AF'] > af_lower) & 
                                               (df_snvs_testing_comb_i['AF'] < af_upper)]
df_snvs_testing_comb_i = df_snvs_testing_comb_i.loc[(df_snvs_testing_comb_i['PERCENT_OVERLAP'] == true_var[0]) |
                                                    (df_snvs_testing_comb_i['PERCENT_OVERLAP'] == false_var[0])]

df_snvs_testing_comb_i.reset_index(drop=True, inplace=True)

# Create a binary response column to identify a variant as true variant (1) or false variant (0)
overlap_cat = list(df_snvs_testing_comb_i['PERCENT_OVERLAP'].apply(lambda x: 1 if x == true_var[0] else 0))
df_snvs_testing_comb_i['OVERLAP_CATEGORY'] = overlap_cat
target_cols = 'OVERLAP_CATEGORY' # Response column 

# Define X and y for testing
X_test = df_snvs_testing_comb_i[feature_cols]
y_test = df_snvs_testing_comb_i[target_cols].tolist()

# Train XGB model with optimum model hyperparameters
eta_opt = 0.2
num_trees_opt = 150
gamma_opt = 2
max_depth_opt = 10
subsample_opt = 1
colsample_opt = 0.5
reg_lambda_opt = 0
reg_alpha_opt = 0

xgb_model = XGBClassifier(use_label_encoder=False, 
                      booster='gbtree', # boosting algorithm to use, default gbtree, othera: gblinear, dart
                      n_estimators=num_trees_opt, # number of trees, default = 100
                      eta=eta_opt, # this is learning rate, default = 0.3
                      max_depth=max_depth_opt, # maximum depth of the tree, default = 6
                      gamma = gamma_opt, # used for pruning, if gain < gamma the branch will be pruned, default = 0
                      reg_lambda = reg_lambda_opt, # regularization parameter, defautl = 1
                      eval_metric = 'logloss',
                      colsample_bytree = colsample_opt,
                      alpha = reg_alpha_opt,
                      subsample = subsample_opt)
fpr_tpr = [] # Store all the fpr, tpr values for each model 
auc_scores = []
df_y_pred_all_models = pd.DataFrame()
df_y_scores_all_models = pd.DataFrame()
df_all_cv_scores = pd.DataFrame()
df_feature_importances_all_models = pd.DataFrame()
for model_i in list(train_sample.keys()):
    X_train_model_i = train_sample[model_i]['X_train']
    y_train_model_i = train_sample[model_i]['y_train']
#         print (f"Running CV and predictions for model {model_i}...", end='', flush=True)
    X_train_model_i = X_train_model_i.apply(pd.to_numeric)
    xgb_model.fit(X_train_model_i,y_train_model_i)

    # Predict using model_i on the test data
    y_pred = xgb_model.predict(X_test)
    df_y_pred_all_models[f"Model_{model_i}"] = y_pred
    y_test_pred_scores = xgb_model.predict_proba(X_test)[:, 1]
    df_y_scores_all_models[f"Model_{model_i}"] = y_test_pred_scores
    false_positive, true_positive, _ = roc_curve(y_test, y_test_pred_scores)
    fpr_tpr.append([false_positive,true_positive])
    # Calculate ROC only if both true and false labels are present.
    # Otherwise, the function roc_auc_score returns error.
    if len(set(y_test)) == 2:
        auc_test = roc_auc_score(y_test, y_pred)
    else:
        auc_test = math.nan
    auc_scores.append(auc_test)
    
    # Save the model with joblib
    joblib.dump(xgb_model, model_dir + "_".join(["xgb_model", str(model_i)]))  
# Calculate metrics only if y_test has both true and false iSNVs labels.
# Otherwise, the AUC cannot be calculated as the function roc_auc_score returns error.
if len(set(y_test)) == 2:
    # Get the consensus predictions from all models
    y_pred_consensus = get_ensemble_prediction(df_y_scores_all_models)

    # Calculate metrics on the consensus prediction
    auc_test = roc_auc_score(y_test, y_pred_consensus)

    # Calculate the F1 score
    F1_score_test = round(f1_score(y_test, y_pred_consensus), 3)

    # Calculate the mean-squared error
    mse_test = round(mean_squared_error(y_test, y_pred_consensus), 3)

    # Calculate the accuracy
    accuracy_test = round(accuracy_score(y_test, y_pred_consensus), 3)

    # Calculate the MCC
    mcc_test = round(matthews_corrcoef(y_test, y_pred_consensus), 3)

    # Print the performance metrics on test data
    # Uncomment to see the metrics for each combination
    print ("AUC =", round(auc_test, 3), ", F1 score =", F1_score_test, ", Mean-squared error =", mse_test, ", Accuracy =", accuracy_test, ", Matthews correlation coefficient =", mcc_test)

    # Get the confusion matrix
    cm = confusion_matrix(y_test, y_pred_consensus)

    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
else:
    # Get the indices of false positives
    false_positive_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true positives
    true_positive_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 1)[0])))
    # Get the indices of true negatives
    true_negative_ind = list(set(np.where(np.array(y_test) == 0)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))
    # Get the indices of false negatives
    false_negative_ind = list(set(np.where(np.array(y_test) == 1)[0]).intersection(set(np.where(np.array(y_pred_consensus) == 0)[0])))

    fp = len(false_positive_ind)
    tp = len(true_positive_ind)
    tn = len(true_negative_ind)
    fn = len(false_negative_ind)
    auc_test = math.nan
    mcc_test = math.nan
    F1_score_test = math.nan
    accuracy_test = math.nan
    mse_test = math.nan

cols = ['Seed', 'True_Var_Def', 'False_Var_Def', 'VAF_Lower_Limit', 'VAF_Upper_Limit',  'Feature_Category',
        'Num_True_Var_Testing', 'Num_False_Var_Testing', 'TP', 'FP', 'TN', 'FN', 'AUC', 'MCC', 
        'F1_score', 'Accuracy', 'MSE']

# Add an additional space before the true var def and false var def. Otherwise, excel formats it as date.
df_tmp = pd.DataFrame(data=[[seed_i, true_var, false_var,af_lower,af_upper,feature_cat, 
                             tp+fn, tn+fp, tp, fp, tn, fn, auc_test, mcc_test, F1_score_test,
                             accuracy_test, mse_test]], columns=cols)
# Out:
# testing samples = ['sample6', 'sample21', 'sample31', 'sample14', 'sample7', 'sample29']
# Running predictions for all parameter/feature combinations with seed 252 ...	Train-test split resulted in imbalanced training data
# 	Over-represented class = 0, count = 3377
# 	Under-represented class = 1, count = 402
# 	Will proceed by creating balanced training data.
# AUC = 0.847 , F1 score = 0.68 , Mean-squared error = 0.132 , Accuracy = 0.868 , Matthews correlation coefficient = 0.613
